# %% [markdown]
# # This notebook is the step-by-step on how to extract the data from https://materialdistrict.com

# %% [markdown]
# ## 0. Setup

# %%
import time, random, re
from urllib import robotparser
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

BASE = "https://materialdistrict.com"
HDRS = {
    "User-Agent": "Academic research bot (non-commercial) <you@your.edu>",
    "Accept-Language": "en-US,en;q=0.9",
}

def get(url, **kw):
    """Small wrapper with headers + timeout."""
    return requests.get(url, headers=HDRS, timeout=kw.pop("timeout", 30), **kw)

def show(text, max_chars=1200):
    """Pretty truncate long text prints."""
    t = text if isinstance(text, str) else str(text)
    print(t if len(t) <= max_chars else t[:max_chars] + "\n... [truncated]")

# %% [markdown]
# ## 1. Check `robots.txt`

# %%
robots_url = urljoin(BASE, "/robots.txt")
r = get(robots_url)
r.raise_for_status()
print("robots.txt URL:", robots_url)
show(r.text)

# Parse with robotparser to programmatically check specific paths
rp = robotparser.RobotFileParser()
rp.set_url(robots_url)
rp.parse(r.text.splitlines())

paths_to_check = [
    "/",
    "/material/",
    "/material/page/1/",
    "/material/mycelium-foam/",
    "/wp-json/",
    "/wp-admin/",
]

ua = HDRS["User-Agent"]
print("\nCan we fetch these paths?")
for p in paths_to_check:
    print(f"{p:35} -> {rp.can_fetch(ua, urljoin(BASE, p))}")
# Out:
# robots.txt URL: https://materialdistrict.com/robots.txt
# User-agent: *
# Disallow: /wp-admin/
# Disallow: /wp-includes/
# Disallow: /themes/
# Disallow: /85712959/
#
# User-agent: Googlebot
# Allow: /wp-admin/css
# Allow: /wp-admin/js
#
# Can we fetch these paths?
# /                                   -> True
# /material/                          -> True
# /material/page/1/                   -> True
# /material/mycelium-foam/            -> True
# /wp-json/                           -> True
# /wp-admin/                          -> False

# %% [markdown]
# ## 2. Try the sitemap index

# %%
sitemap_index = urljoin(BASE, "/sitemap_index.xml")
resp = get(sitemap_index)
print("Sitemap index status:", resp.status_code)
if resp.ok:
    soup = BeautifulSoup(resp.text, "xml")  # XML parser
    locs = [loc.get_text(strip=True) for loc in soup.find_all("loc")]
    print(f"Found {len(locs)} sitemap files.")
    # show a few:
    for u in locs[55:65]:
        print("  -", u)
else:
    show(resp.text)
# Out:
# Sitemap index status: 200
# Found 83 sitemap files.
#   - https://materialdistrict.com/brand-sitemap2.xml
#   - https://materialdistrict.com/brand-sitemap3.xml
#   - https://materialdistrict.com/material-sitemap.xml
#   - https://materialdistrict.com/material-sitemap2.xml
#   - https://materialdistrict.com/material-sitemap3.xml
#   - https://materialdistrict.com/material-sitemap4.xml
#   - https://materialdistrict.com/post_tag-sitemap.xml
#   - https://materialdistrict.com/post_tag-sitemap2.xml
#   - https://materialdistrict.com/persons-sitemap.xml
#   - https://materialdistrict.com/sector-sitemap.xml

# %% [markdown]
# ## 3. Keep only material sitemaps

# %%
material_sitemaps = [u for u in locs if "material-sitemap" in u.lower()]
print("Material sitemaps:", len(material_sitemaps))
for u in material_sitemaps:
    print(" -", u)
# Out:
# Material sitemaps: 4
#  - https://materialdistrict.com/material-sitemap.xml
#  - https://materialdistrict.com/material-sitemap2.xml
#  - https://materialdistrict.com/material-sitemap3.xml
#  - https://materialdistrict.com/material-sitemap4.xml

# %% [markdown]
# ## 4. Extract all `/material/...` URLs from those sitemaps

# %%
def urls_from_sitemap(url: str):
    r = requests.get(url, headers=HDRS, timeout=30)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "xml")
    urls = []
    for loc in soup.find_all("loc"):
        u = loc.get_text(strip=True)
        if "/material/" in u:
            urls.append(u)
    return urls

all_material_urls = []
for sm in material_sitemaps:
    time.sleep(random.uniform(0.8, 1.5))   # polite delay
    subset = urls_from_sitemap(sm)
    print(f"{sm} -> {len(subset)} urls")
    all_material_urls.extend(subset)

# de-duplicate + sort
all_material_urls = sorted(set(all_material_urls))
print("\nTOTAL unique material URLs:", len(all_material_urls))
for u in all_material_urls[:10]:
    print("  -", u)
# Out:
# https://materialdistrict.com/material-sitemap.xml -> 1001 urls
# https://materialdistrict.com/material-sitemap2.xml -> 1000 urls
# https://materialdistrict.com/material-sitemap3.xml -> 1000 urls
# https://materialdistrict.com/material-sitemap4.xml -> 163 urls
#
# TOTAL unique material URLs: 3164
#   - https://materialdistrict.com/material/
#   - https://materialdistrict.com/material/013-denim/
#   - https://materialdistrict.com/material/100-bacterial-dye/
#   - https://materialdistrict.com/material/100-basalt-fabric/
#   - https://materialdistrict.com/material/100-biobased-flax-panel/
#   - https://materialdistrict.com/material/100-rejects-waxed-printed-cotton/
#   - https://materialdistrict.com/material/2-000-000-000-precious-pieces/
#   - https://materialdistrict.com/material/2-5d-print/
#   - https://materialdistrict.com/material/2000n-pressed-shoe/
#   - https://materialdistrict.com/material/2tec2-high-tech-flooring/

# %% [markdown]
# ## 5. Sanity-check a few pages (status + `<title>`)

# %%
def peek_title(html: str) -> str:
    # quick & tiny title scrape (faster than a full parse)
    m = re.search(r"<title>(.*?)</title>", html, flags=re.I|re.S)
    return (m.group(1).strip() if m else "").replace("\n", " ")

sample = random.sample(all_material_urls, k=min(5, len(all_material_urls)))
print("Sampling", len(sample), "pages...\n")

for u in sample:
    r = requests.get(u, headers=HDRS, timeout=30)
    print(r.status_code, "-", u)
    if r.ok:
        print("   ", peek_title(r.text)[:120])
    time.sleep(random.uniform(0.8, 1.5))
# Out:
# Sampling 5 pages...
#
# 200 - https://materialdistrict.com/material/pet-felt-acoustic-panels-stripes/
#     PET Felt Acoustic Panels Stripes - MaterialDistrict
# 200 - https://materialdistrict.com/material/evergreen/
#     Evergreen - MaterialDistrict
# 200 - https://materialdistrict.com/material/tectonitx/
#     tectonitX™ - MaterialDistrict
# 200 - https://materialdistrict.com/material/pet-felt-wall-shingles-round/
#     PET Felt Wall Shingles Round - MaterialDistrict
# 200 - https://materialdistrict.com/material/3d-printed-concrete/
#     3D printed concrete - MaterialDistrict

# %% [markdown]
# ## 6. Save URL list

# %%
import json, csv, pathlib

out_dir = pathlib.Path(".")
out_dir.mkdir(parents=True, exist_ok=True)

with open(out_dir / "material_urls.csv", "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f); w.writerow(["url"]); w.writerows([[u] for u in all_material_urls[1:]]) # Because first URL is general page

print("Saved:",
      (out_dir / "material_urls.csv").resolve(), sep="\n - ")
# Out:
# Saved:
#  - /Users/juanesfco/MaterialNet/data/material_urls.csv

# %% [markdown]
# ## 7. Load URL list

# %%
import csv

material_urls_list = []
with open('material_urls.csv', newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        material_urls_list.append(row['url'])

print(f"Loaded {len(material_urls_list)} URLs.")
material_urls_list[:5]  # Show a sample
# Out:
# Loaded 3163 URLs.
# ['https://materialdistrict.com/material/013-denim/',
#  'https://materialdistrict.com/material/100-bacterial-dye/',
#  'https://materialdistrict.com/material/100-basalt-fabric/',
#  'https://materialdistrict.com/material/100-biobased-flax-panel/',
#  'https://materialdistrict.com/material/100-rejects-waxed-printed-cotton/']

# %% [markdown]
# ## 8. Pick test URL

# %%
TEST_URL = material_urls_list[0]
print("Test URL:", TEST_URL)
# Out:
# Test URL: https://materialdistrict.com/material/013-denim/

# %% [markdown]
# ## 9. Helpers to fetch page information

# %%
import re, time, requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

SESSION = requests.Session()
SESSION.headers.update({
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) MaterialNetBot/0.1 (+research; contact me)"
})

def fetch_html(url, *, sleep=0.5, timeout=20):
    resp = SESSION.get(url, timeout=timeout)
    time.sleep(sleep)
    resp.raise_for_status()
    return BeautifulSoup(resp.text, "lxml"), resp.text

_ws_re = re.compile(r"\s+")
def _clean(s):
    return _ws_re.sub(" ", s).strip() if s else None

# %% [markdown]
# ## 10. Parsers for the desired fields

# %%
# Title
def parse_title(soup: BeautifulSoup):
    # Primary
    h1 = soup.select_one(".row.title h1") or soup.find("h1")
    if h1 and _clean(h1.get_text()):
        return _clean(h1.get_text())
    # Fallback to OG/Schema
    og = soup.find("meta", property="og:title")
    if og and og.get("content"):
        # Remove suffix " - MaterialDistrict"
        return _clean(re.sub(r"\s*-\s*MaterialDistrict\s*$", "", og["content"]))
    return None


# Subtitle
def parse_subtitle_meta(soup: BeautifulSoup):
    want = {"Category": None, "Code": None, "Country": None, "Brand": None}
    row = soup.select_one(".row.subtitle")
    if not row:
        return want

    # Each item is a "div.block" with <h6>Label</h6> followed by either text or <a>
    for blk in row.select(".block"):
        label = blk.find("h6")
        if not label:
            continue
        key = _clean(label.get_text()).title()
        if key not in want:
            continue

        a = blk.find("a")
        if a:
            want[key] = _clean(a.get_text())
        else:
            # Text can be mixed; remove the <h6> text from the block's text
            raw = _clean(blk.get_text(" "))
            if raw:
                val = _clean(raw.replace(_clean(label.get_text()), "", 1))
                want[key] = val or None

    return want

# Body text
def _find_main_post_block(soup: BeautifulSoup):
    """
    Typical post content lives in a <div class="block ... material type-material ... post-XXXXX ...">
    We match both 'material' AND 'type-material' and any class starting with 'post-'.
    """
    candidates = []
    for div in soup.select("div.block"):
        classes = set(div.get("class") or [])
        if "material" in classes and "type-material" in classes:
            if any(c.startswith("post-") for c in classes):
                candidates.append(div)
    # Prefer the longest text block if multiple match
    if not candidates:
        # Fallbacks: two-thirds column, hentry, etc.
        candidates = soup.select("article .col.two-thirds div.block")
    if not candidates:
        return None
    return max(candidates, key=lambda d: len(d.get_text(" ").strip()))

def parse_post_paragraphs_list(soup: BeautifulSoup):
    block = _find_main_post_block(soup)
    pars = []
    if block:
        for p in block.find_all("p"):
            txt = _clean(p.get_text(" "))
            if txt:
                pars.append(txt)
    return pars

def parse_post_text(soup: BeautifulSoup, joiner="\n\n"):
    return joiner.join(parse_post_paragraphs_list(soup))

# Material properties
def parse_material_properties(soup: BeautifulSoup):
    root = soup.select_one(".row.material-properties")
    if not root:
        return {}

    groups = {}
    # Each column has one <ul>; the first <li><strong>...</strong></li> is the group title
    for ul in root.select(".col .block ul"):
        # Group title
        title_li = ul.find("li")
        if not title_li:
            continue
        strong = title_li.find("strong")
        group_name = _clean(strong.get_text()) if strong else None
        if not group_name:
            continue

        props = {}
        for li in ul.find_all("li")[1:]:
            label_el = li.find("span", class_="property")
            if not label_el:
                continue
            label = _clean(label_el.get_text())

            # value might be in <a>, possibly wrapped in <span class="important">
            val_el = None
            # Prefer an <span class="important"> wrapper if present
            imp = li.find("span", class_="important")
            if imp and imp.find("a"):
                val_el = imp.find("a")
            elif li.find("a"):
                val_el = li.find("a")
            else:
                # as plain text after the label span
                label_text = _clean(label_el.get_text())
                li_text = _clean(li.get_text(" "))
                if li_text and label_text:
                    # drop the label from the beginning
                    tail = _clean(li_text.replace(label_text, "", 1))
                    val = tail
                else:
                    val = None
                props[label] = val
                continue

            val = _clean(val_el.get_text()) if val_el else None
            props[label] = val

        if props:
            groups[group_name] = props

    return groups

# Tags
def parse_material_tags(soup: BeautifulSoup):
    root = soup.select_one(".row.material-properties")
    if not root:
        return []
    tag_ul = root.select_one("ul.taglist")
    if not tag_ul:
        return []

    tags = []
    for a in tag_ul.select("a[rel='tag']"):
        t = _clean(a.get_text())
        if t:
            tags.append(t)

    # de-dupe while preserving order
    seen, out = set(), []
    for t in tags:
        if t not in seen:
            seen.add(t)
            out.append(t)
    return out

# Complete parser
def parse_material_page(url: str):
    soup, raw = fetch_html(url)
    meta = parse_subtitle_meta(soup)
    data = {
        "url": url,
        "material_name": parse_title(soup),
        "Category": meta.get("Category"),
        "Code": meta.get("Code"),
        "Country": meta.get("Country"),
        "Brand": meta.get("Brand"),
        "post_text": parse_post_text(soup, joiner="\n\n"),
        "post_paragraphs": parse_post_paragraphs_list(soup),
        "material_properties": parse_material_properties(soup),
        "tags": parse_material_tags(soup),
    }
    return data

# %% [markdown]
# ## 11. Run on test page

# %%
data = parse_material_page(TEST_URL)
for k in ("material_name","Category","Code","Country","Brand"):
    print(f"{k:>16}:", data[k])
print("tags:", data["tags"])
print("properties groups:", list(data["material_properties"].keys()))
print("post_text preview:", data["post_text"][:300], "...\n")
# Out:
#    material_name: 013 Denim
#         Category: Other naturals
#             Code: ONA791
#          Country: Netherlands
#            Brand: 013 Denim
# tags: ['Biobased', 'Recycling', 'Sustainable', 'Other naturals', 'fabric', 'textile']
# properties groups: ['Sensorial', 'Technical']
# post_text preview: 013 Denim is made 50% from recycled denim garments from Tilburg and 50% from organic cotton yarn from India. For the first production, the denim garments were collected in February 2017 by residents of Tilburg and 6 primary schools in the city. The denim garments were then recycled into denim yarn b ...

# %% [markdown]
# ## 12. Read URLs from CSV

# %%
import pandas as pd

# Assume your CSV has a column called 'url' or similar
urls_df = pd.read_csv("material_urls.csv")
urls = urls_df.loc[:,'url'].dropna().tolist()
print(f"Loaded {len(urls)} URLs")
# Out:
# Loaded 3163 URLs

# %% [markdown]
# ## 13. Crawl and parse all pages

# %%
results = []

for i, url in enumerate(urls, 1):
    try:
        data = parse_material_page(url)
        results.append(data)
        print(f"[{i}/{len(urls)}] OK: {data['material_name']}")
    except Exception as e:
        print(f"[{i}/{len(urls)}] ERROR on {url}: {e}")
# Out:
# [1/3163] OK: 013 Denim
# [2/3163] OK: 100% bacterial dye
# [3/3163] OK: Basalt knitted fabric
# [4/3163] OK: 100% Biobased Flax panel
# [5/3163] OK: 100% rejects waxed printed cotton
# [6/3163] OK: 2,000,000,000 Precious Pieces
# [7/3163] OK: 2.5D print
# [8/3163] OK: 2000N Pressed Shoe
# [9/3163] OK: 2tec2 high tech flooring
# [10/3163] OK: 2tec2 – Marble & Desert
# [11/3163] OK: 2TEC2
# [12/3163] OK: 3D Veneer
# [13/3163] OK: 37.5 technology CVC Woven
# [14/3163] OK: 37.5 technology WPB laminate
# [15/3163] OK: 3D Bamboo Wall panels
# [16/3163] OK: 3D biaxial knitted fabric
# [17/3163] OK: 3D Brocade all-over Lurex
# [18/3163] OK: 3D Composites
# [19/3163] OK: 3D core
# [20/3163] OK: 3d-design
# [21/3163] OK: 3D Engineered Sound Barrier
# [22/3163] OK: 3D Engraved Glass
# [23/3163] OK: 3D Felt Tiles
# [24/3163] OK: 3D knitted CC cubic acoustic fabric
# [25/3163] OK: 3D knitted jersey
# [26/3163] OK: 3D Leveling Cork
# [27/3163] OK: 3D Metal
# [28/3163] OK: 3D Plate
# [29/3163] OK: 3D print on stretch fabric
# [30/3163] OK: 3D printed concrete
# [31/3163] OK: 3D printed Earth
# [32/3163] OK: 3D Printed Surface
# [33/3163] OK: 3D Printing Clay facade bricks
# [34/3163] OK: 3D Printing Eggshell Bioceramic
# [35/3163] OK: 3D Profile
# [36/3163] OK: 3D Series
# [37/3163] OK: 3D Smoke Out
# [38/3163] OK: 3D stretch
# [39/3163] OK: 3D-Tex PES / PP KHF
# [40/3163] OK: 3D Textile
# [41/3163] OK: 3D Textiles by Gaetano Rossini
# [42/3163] OK: 3D Textiles
# [43/3163] OK: 3D Textilles
# [44/3163] OK: 3D wood
# [45/3163] OK: 3mesh
# [46/3163] OK: 4 Outdoor
# [47/3163] OK: 4Design panels
# [48/3163] OK: 850°C Ash concrete
# [49/3163] OK: Abacá
# [50/3163] OK: Abstract Mirror
# [51/3163] OK: Accoya
# [52/3163] OK: Accura Bluestone Plastic
# [53/3163] OK: Acilux
# [54/3163] OK: Acospray
# [55/3163] OK: Acoustic-Baffles
# [56/3163] OK: Acoustic Ceiling Spray-on Solutions
# [57/3163] OK: Acoustic cork wall tiles
# [58/3163] OK: Acoustic elements
# [59/3163] OK: Acoustic-Grilles
# [60/3163] OK: Acoustic high performance sheets
# [61/3163] OK: Acoustic-Lightboard Platten
# [62/3163] OK: Acoustic metal
# [63/3163] OK: Acoustic peat panels
# [64/3163] OK: Acoustic reed elements
# [65/3163] OK: Acoustic-RibPanel Slim
# [66/3163] OK: Acoustic-RibPanel
# [67/3163] OK: Acoustic textile felt
# [68/3163] OK: Acoustic Textile
# [69/3163] OK: Acoustic Veneered Wood Wall & Ceiling Panels
# [70/3163] OK: Acoustic Wool Felt Rigid
# [71/3163] OK: Acoustics 3D full colour felt
# [72/3163] OK: Acrylic Couture
# [73/3163] OK: Acrylic One
# [74/3163] OK: Acrylic
# [75/3163] OK: Acrysmart
# [76/3163] OK: ACT WRM
# [77/3163] OK: Activ selfcleaning glass
# [78/3163] OK: Active Protection System
# [79/3163] OK: Adamant Textile
# [80/3163] OK: Advantic Syntactic Foam
# [81/3163] OK: Aectual Wrap Panel
# [82/3163] OK: Aeras
# [83/3163] OK: Aeria
# [84/3163] OK: Aerialite
# [85/3163] OK: Aerogel
# [86/3163] OK: Aestetica composites
# [87/3163] OK: Aesthetical Ceramics
# [88/3163] OK: Agribiopanel
# [89/3163] OK: Agriluma (Agrimat)
# [90/3163] OK: AGT Glow Sand
# [91/3163] OK: AgUARDIAN
# [92/3163] OK: Airflake
# [93/3163] OK: AirMaxx
# [94/3163] OK: Aisti® Teno acoustic tile
# [95/3163] OK: Akdolam lightweight stone panels
# [96/3163] OK: Akzent panels
# [97/3163] OK: AL100 wall shield
# [98/3163] OK: Albeflex
# [99/3163] OK: Alchimea lana
# [100/3163] OK: ALCHIMIA – Natural Yarn dyes on Milk fibre
# [101/3163] OK: Alesta Powder Coating – The Finetextured Collection
# [102/3163] OK: Algae-based biopolymer
# [103/3163] OK: Algae foam
# [104/3163] OK: Algal Tiles
# [105/3163] OK: AlgoRythm
# [106/3163] OK: Alicrite String
# [107/3163] OK: ALKEMI-acrylic
# [108/3163] OK: Alkorfol
# [109/3163] OK: All-round heating
# [110/3163] OK: Allison
# [111/3163] OK: Allura
# [112/3163] OK: Allure & Manhattan
# [113/3163] OK: Almaxco Composite Panels
# [114/3163] OK: Alouette
# [115/3163] OK: Alpha Gel
# [116/3163] OK: Alpha Tacto
# [117/3163] OK: Alphamesh
# [118/3163] OK: Alpikord
# [119/3163] OK: ALPIlignum
# [120/3163] OK: Alpilignum – Design Collection
# [121/3163] OK: Alpolic
# [122/3163] OK: Alrox
# [123/3163] OK: Altuglas Dual Satin
# [124/3163] OK: Aluben
# [125/3163] OK: ALUCOBOND®
# [126/3163] OK: Alulife
# [127/3163] OK: Alulight
# [128/3163] OK: Alumero Diamond Line
# [129/3163] OK: Aluminium Cladding
# [130/3163] OK: Aluminium Foam Glass Sandwich
# [131/3163] OK: Aluminium foam with salt
# [132/3163] OK: Aluminium foam
# [133/3163] OK: Aluminium frame facade panels
# [134/3163] OK: Aluminium full colour
# [135/3163] OK: Aluminium mesh
# [136/3163] OK: Aluminium wall panels
# [137/3163] OK: Aluminium Surface Collections
# [138/3163] OK: aluminium tile
# [139/3163] OK: AluOldCopper
# [140/3163] OK: Alusion Large & Small Cells
# [141/3163] OK: Alveo Products
# [142/3163] OK: Amadou
# [143/3163] OK: Amber Waste is Bliss
# [144/3163] OK: Ambient Glow Technology
# [145/3163] OK: Amphitex™
# [146/3163] OK: ampliTex powerRibs
# [147/3163] OK: An-Jing Paper
# [148/3163] OK: Andeline Recycled Leather
# [149/3163] OK: Andy
# [150/3163] OK: ANEMONIA
# [151/3163] OK: Animal & Leather Print Tiles
# [152/3163] OK: Another Down & Another Down recycled
# [153/3163] OK: Antibacterial surfaces
# [154/3163] OK: Antico
# [155/3163] OK: Antimicrobial Copper: Brass
# [156/3163] OK: Antimicrobial Copper: Bronze
# [157/3163] OK: Antimicrobial Copper
# [158/3163] OK: Antiqued mirror and gilded glass
# [159/3163] OK: Antislip tiles
# [160/3163] OK: Antolini
# [161/3163] OK: ANVI Luxury Surfaces
# [162/3163] OK: ANVI Solitaire
# [163/3163] OK: Apex
# [164/3163] OK: Apparition translucent leather
# [165/3163] OK: Apple pomace films
# [166/3163] OK: Aquaclean
# [167/3163] OK: Aquarius
# [168/3163] OK: Aquatecture Water Harvesting Panel
# [169/3163] OK: Aquatic plant paper
# [170/3163] OK: ARA-LT laser film
# [171/3163] OK: Arboform
# [172/3163] OK: ArboSkin
# [173/3163] OK: ArcBiox BGF30-A1 and ArcBiox A17
# [174/3163] OK: Arce’s 3D Tiles
# [175/3163] OK: Archi Folds
# [176/3163] OK: Archi+ Tadelakt
# [177/3163] OK: ARCHISONIC® Cotton
# [178/3163] OK: ARCHISONIC® Felt
# [179/3163] OK: ARCHISONIC® Textile
# [180/3163] OK: Architectural Glass Surfaces
# [181/3163] OK: Architectural Glass
# [182/3163] OK: Architectural mesh
# [183/3163] OK: Architectural Metals
# [184/3163] OK: Architectural sheets
# [185/3163] OK: Architectural Titanium
# [186/3163] OK: Architextile
# [187/3163] OK: Ardomix
# [188/3163] OK: Arfinio®
# [189/3163] OK: Ariel 4311
# [190/3163] OK: Armourcast
# [191/3163] OK: AROMA AQ
# [192/3163] OK: Arpex EPE
# [193/3163] OK: ARPRO P-EPP
# [194/3163] OK: Arpro
# [195/3163] OK: Arrigado
# [196/3163] OK: Arstyl
# [197/3163] OK: Art Ferro
# [198/3163] OK: Art Intervention
# [199/3163] OK: Art on Tiles
# [200/3163] OK: Art panel
# [201/3163] OK: Artile
# [202/3163] OK: Artos
# [203/3163] OK: Artstone
# [204/3163] OK: Asian Canvas
# [205/3163] OK: Astrale
# [206/3163] OK: Atelier Barb Bio Series
# [207/3163] OK: Atelier Collection
# [208/3163] OK: Atex Colour
# [209/3163] OK: Atex Screen
# [210/3163] OK: Atex
# [211/3163] OK: Atlantique
# [212/3163] OK: Atmospheric Wood
# [213/3163] OK: Attraction
# [214/3163] OK: Aurea
# [215/3163] OK: Autarchy
# [216/3163] OK: Autoheal
# [217/3163] OK: Automatic & Serendpt
# [218/3163] OK: Avocado Seed Bricks
# [219/3163] OK: Avonite Glass Series
# [220/3163] OK: Avonite Petals Series
# [221/3163] OK: Avonite Recycled Acrylic Series
# [222/3163] OK: Avonite
# [223/3163] OK: Awakyuki – Melting Snow
# [224/3163] OK: Axpoly
# [225/3163] OK: Ayrlite Sonium
# [226/3163] OK: B-Clear
# [227/3163] OK: B.Cork
# [228/3163] OK: Baby Merino
# [229/3163] OK: Backlight Images
# [230/3163] OK: Bacterial cellulose
# [231/3163] OK: Bahia
# [232/3163] OK: Baileo Envi Neo Pyramid
# [233/3163] OK: Balsa Platte Lightwood B1
# [234/3163] OK: Balsaboard Lightwood
# [235/3163] OK: BalsaConcrete
# [236/3163] OK: Balsatec
# [237/3163] OK: Bamboo 3D Panels
# [238/3163] OK: Bamboo Elite Premium
# [239/3163] OK: Bamboo fibres
# [240/3163] OK: Bamboo Groove & Star Canopy
# [241/3163] OK: Bamboo mosaic
# [242/3163] OK: Bamboo panels
# [243/3163] OK: Bamboo UltraDensity heavy duty flooring
# [244/3163] OK: Bamboo veneer
# [245/3163] OK: Banana fibre, hemp & jute carpet
# [246/3163] OK: Banana fibre paper
# [247/3163] OK: Bananatex®
# [248/3163] OK: Baq+
# [249/3163] OK: Barbara Steinmann
# [250/3163] OK: Barcode
# [251/3163] OK: Bark Cloth
# [252/3163] OK: Bark
# [253/3163] OK: Barkcloth HPL
# [254/3163] OK: Barkskin
# [255/3163] OK: Barktex
# [256/3163] OK: Barlo Cast Design
# [257/3163] OK: Barlo SPC Diamond
# [258/3163] OK: Barnwood
# [259/3163] OK: Barracuda Aluminized Fabric
# [260/3163] OK: Barricada
# [261/3163] OK: Barrique boden
# [262/3163] OK: Barrisol Biosource
# [263/3163] OK: Barrisol Clim
# [264/3163] OK: BARRISOL MIRROR®
# [265/3163] OK: Barrisol
# [266/3163] OK: Basalt Tiles
# [267/3163] OK: Basalt Woven Textile
# [268/3163] OK: Base Superbo
# [269/3163] OK: Baswa acoustic plaster
# [270/3163] OK: Batyline Canatex
# [271/3163] OK: BauBuche Beam
# [272/3163] OK: Bauxite Residue ceramics
# [273/3163] OK: Bcomp Textile
# [274/3163] OK: bCore
# [275/3163] OK: Beadazzled
# [276/3163] OK: Bealstone
# [277/3163] OK: Beaufort
# [278/3163] OK: Bee_bo
# [279/3163] OK: BeeBoard
# [280/3163] OK: Beeksteen
# [281/3163] OK: Beetlecrete – MPBWC
# [282/3163] OK: Bekaert Bekinox VN
# [283/3163] OK: Bekaert Quench Products
# [284/3163] OK: BELEAF
# [285/3163] OK: Belgian Linen
# [286/3163] OK: Belin
# [287/3163] OK: Belle Naturelle
# [288/3163] OK: Belpasso Premio, Cleantop
# [289/3163] OK: Belt
# [290/3163] OK: BELTWALK
# [291/3163] OK: Benchmark
# [292/3163] OK: Bendywood
# [293/3163] OK: Bera Gravel Fix
# [294/3163] OK: Berriestex – Made from strawberries
# [295/3163] OK: BESE-elements®
# [296/3163] OK: Bespoke 3D Leather
# [297/3163] OK: BestFelt
# [298/3163] OK: Béton Picturale
# [299/3163] OK: Betonada Rust
# [300/3163] OK: Betonlook paint
# [301/3163] OK: Bia Metallic
# [302/3163] OK: Bianni’ – Wool Paper
# [303/3163] OK: Bicicleta rug
# [304/3163] OK: Big Mesh
# [305/3163] OK: Bio-AmiCoFitex
# [306/3163] OK: Bio-Construct
# [307/3163] OK: Bio-Flex
# [308/3163] OK: Bio-Glass
# [309/3163] OK: Bio Laminates
# [310/3163] OK: Bio-luminum
# [311/3163] OK: Bio Pigments Atelier
# [312/3163] OK: Bio-receptive 3D printed ceramics
# [313/3163] OK: Bio-SIP™
# [314/3163] OK: Biobased SIP building system
# [315/3163] OK: BioBasedTile®
# [316/3163] OK: Bioblocks
# [317/3163] OK: BioCaif
# [318/3163] OK: Biochar-Cob
# [319/3163] OK: BioCoat
# [320/3163] OK: Biocomposites
# [321/3163] OK: Biodegradable envelopes
# [322/3163] OK: Biofiber
# [323/3163] OK: Bioflexi
# [324/3163] OK: BioFoam
# [325/3163] OK: BioFoamPearls
# [326/3163] OK: Biofold acoustic panel
# [327/3163] OK: Biofuel Waste is Bliss
# [328/3163] OK: Biograde
# [329/3163] OK: Biogranulates
# [330/3163] OK: BioGreen padding polymer
# [331/3163] OK: BioLaminil
# [332/3163] OK: Trifilon BioLite®
# [333/3163] OK: Biological grown material
# [334/3163] OK: Biopanel
# [335/3163] OK: Biophilic Wallpaper
# [336/3163] OK: Biophyl
# [337/3163] OK: Bioplastics from Organic Waste
# [338/3163] OK: Biopregs
# [339/3163] OK: BioProtect
# [340/3163] OK: bios.antibacterial ceramics
# [341/3163] OK: Biosgel
# [342/3163] OK: Biotex
# [343/3163] OK: BirdShades bird protection window film
# [344/3163] OK: Bisazza Mosaico Mix
# [345/3163] OK: Black Gold
# [346/3163] OK: Black Heart
# [347/3163] OK: Black MDF – Fibracolour Negro
# [348/3163] OK: Black N Tan
# [349/3163] OK: Black=Colour
# [350/3163] OK: Blazestone
# [351/3163] OK: Blend
# [352/3163] OK: Blinds made of waste material
# [353/3163] OK: BlingCrete light reflecting concrete
# [354/3163] OK: Blobb Tiles
# [355/3163] OK: Blood bio leather
# [356/3163] OK: Blood plastic
# [357/3163] OK: Blow-in straw fibre insulation
# [358/3163] OK: Blown-up weave 2D & 3D
# [359/3163] OK: Bluedec
# [360/3163] OK: Bluestein
# [361/3163] OK: Bobbles
# [362/3163] OK: BODEM circulair terrazzo
# [363/3163] OK: Body and Soul
# [364/3163] OK: Bog Oak
# [365/3163] OK: Boiled Wood
# [366/3163] OK: Bois Larmé
# [367/3163] OK: Bola TriGlass
# [368/3163] OK: Bolefloor
# [369/3163] OK: Bolidt Flooring
# [370/3163] OK: Bonded Metal
# [371/3163] OK: Bonding technology Biflex
# [372/3163] OK: Boracay
# [373/3163] OK: Borit
# [374/3163] OK: BorjaJet roof tiles
# [375/3163] OK: Botanical C
# [376/3163] OK: Botanical PaperWorks
# [377/3163] OK: Both
# [378/3163] OK: Recycled glass surfaces
# [379/3163] OK: Bouclé & Lounge
# [380/3163] OK: Bouclé
# [381/3163] OK: BRAiDZZ
# [382/3163] OK: Brass & Copper
# [383/3163] OK: Brava
# [384/3163] OK: Breathable PU Fabrics
# [385/3163] OK: Breathaboard
# [386/3163] OK: Breathaplasta wall plaster
# [387/3163] OK: Brick
# [388/3163] OK: Brickbin
# [389/3163] OK: BrickWool
# [390/3163] OK: Brightbond®
# [391/3163] OK: Brisa
# [392/3163] OK: Bristle Technology
# [393/3163] OK: Brock foam
# [394/3163] OK: Brock PowerBase
# [395/3163] OK: Brotzeit End Grain Board
# [396/3163] OK: Bruciato
# [397/3163] OK: Brussels Glass
# [398/3163] OK: BT40 & Raw circular
# [399/3163] OK: Bubbles with Benefits
# [400/3163] OK: Building-Integrated Photovoltaics
# [401/3163] OK: Buildmatterial 0.8
# [402/3163] OK: Burned Wood
# [403/3163] OK: BurntWood ReUse
# [404/3163] OK: Butchers Block
# [405/3163] OK: Butong bubble concrete
# [406/3163] OK: BUXKIN original acoustic panels
# [407/3163] OK: BuzziCube
# [408/3163] OK: Buzzifelt
# [409/3163] OK: BuzziSkin 3D
# [410/3163] OK: Byblos
# [411/3163] OK: C-Slurry
# [412/3163] OK: c_change
# [413/3163] OK: Cabbtex – Made from cabbage
# [414/3163] OK: Cacao Paper
# [415/3163] OK: CaesarStone®
# [416/3163] OK: Cafea Silverskin
# [417/3163] OK: Caju / Soft Velvet, 100% Tencel
# [418/3163] OK: Caleidolegno
# [419/3163] OK: Calignum
# [420/3163] OK: Cameluxe
# [421/3163] OK: Caméléon
# [422/3163] OK: Camsiva
# [423/3163] OK: CaNaDry lime hemp mix
# [424/3163] OK: Canvas – Biobased Rug
# [425/3163] OK: Capitonné
# [426/3163] OK: Capri
# [427/3163] OK: CAPSPLATE®
# [428/3163] OK: Capu-Cell
# [429/3163] OK: MaterialDistrict
# [430/3163] OK: Carbofont
# [431/3163] OK: Carbon Buster
# [432/3163] OK: Carbon Graphite Rigid Felt Board
# [433/3163] OK: Carbon Low panels & grids
# [434/3163] OK: CarbonCast
# [435/3163] OK: Care For Milk ceramic glaze
# [436/3163] OK: Carpet tile
# [437/3163] OK: Carpetlight CL21
# [438/3163] OK: Carpets from Robusta
# [439/3163] OK: Carrelage
# [440/3163] OK: Cartamela
# [441/3163] OK: Carved Panels
# [442/3163] OK: Casaleno
# [443/3163] OK: CasaLuxe
# [444/3163] OK: Casper Cloaking Technology
# [445/3163] OK: Cast Aluminium
# [446/3163] OK: Cast Form
# [447/3163] OK: Cast Glass
# [448/3163] OK: Cast Gypsum Panels
# [449/3163] OK: Cast Polymer
# [450/3163] OK: Castle Stones
# [451/3163] OK: CASULO FELIZ – PRIMITIVE SILK
# [452/3163] OK: Caura
# [453/3163] OK: “CAVA” SPARKLING BY NATURE
# [454/3163] OK: CD
# [455/3163] OK: Celestial Night
# [456/3163] OK: Cell-carpet LED
# [457/3163] OK: Cellular – the breathing facade tile
# [458/3163] OK: Cempanit
# [459/3163] OK: Cerablanket
# [460/3163] OK: CERALUTION Versaflex
# [461/3163] OK: Ceramic foam filters
# [462/3163] OK: Ceramic Print
# [463/3163] OK: Ceramic sand
# [464/3163] OK: Ceramic Steel
# [465/3163] OK: Ceramic surface
# [466/3163] OK: Ceramic Textile
# [467/3163] OK: Ceramic Wall Cladding
# [468/3163] OK: Ceranex
# [469/3163] OK: CETEC
# [470/3163] OK: Chameleon Beads
# [471/3163] OK: Chameleon collection
# [472/3163] OK: Chameleon Fabrics
# [473/3163] OK: Changeable Reflective Textiles
# [474/3163] OK: Checked copper fabric
# [475/3163] OK: Chenille Viscose
# [476/3163] OK: Chimera by Shai Langen
# [477/3163] OK: ChipChain
# [478/3163] OK: Chipps design OSB
# [479/3163] OK: Chocolate stone border
# [480/3163] OK: Chroma
# [481/3163] OK: Chromashine
# [482/3163] OK: Chromazone
# [483/3163] OK: Chrome-optics
# [484/3163] OK: Chromyx
# [485/3163] OK: Ciba XYMARA Electra inks
# [486/3163] OK: CicloBrick
# [487/3163] OK: CIMENTO®
# [488/3163] OK: Circlefoam recycled pu foam
# [489/3163] OK: Circles
# [490/3163] OK: CircuGlue Light, Medium, Heavy
# [491/3163] OK: Circular Ceramics
# [492/3163] OK: Circular Collection – Shadows of Light
# [493/3163] OK: Circular Concrete Cityscapes
# [494/3163] OK: Circular Modular carpets
# [495/3163] OK: Circular Terrazzo
# [496/3163] OK: Circulation (HIVE)
# [497/3163] OK: Cirt Piedra
# [498/3163] OK: Citrustex – Made from citrus
# [499/3163] OK: Classic-Panels Classic-Light
# [500/3163] OK: Classic-Panels Classic-Stone
# [501/3163] OK: Classico
# [502/3163] OK: Clay Plaster
# [503/3163] OK: Claylime natural plasters
# [504/3163] OK: Claytec
# [505/3163] OK: Claything
# [506/3163] OK: Cleaf
# [507/3163] OK: Clean Air City Ceramics – bronze glaze
# [508/3163] OK: Clean Air City Ceramics – waste glazes
# [509/3163] OK: CLEAN-AIR-CITY-CERAMICS
# [510/3163] OK: Clear-PEP and AIR-board
# [511/3163] OK: Clear TPU flock
# [512/3163] OK: Clearsorber
# [513/3163] OK: Cleartint
# [514/3163] OK: Climacustic
# [515/3163] OK: ClimaLife
# [516/3163] OK: Climaplus Solar Control
# [517/3163] OK: Climatex Dualcycle
# [518/3163] OK: Climatex Lifecycle
# [519/3163] OK: Climatex LifeguardFR
# [520/3163] OK: Cloud Softlight
# [521/3163] OK: Cloudwool
# [522/3163] OK: Cloudy
# [523/3163] OK: Club
# [524/3163] OK: Coarse Concrete
# [525/3163] OK: Coatacoustic
# [526/3163] OK: Coated Aluminium
# [527/3163] OK: Coated linen slub
# [528/3163] OK: CobalTex
# [529/3163] OK: Cocoa Marmoleum
# [530/3163] OK: COCOA
# [531/3163] OK: Cocoboard©
# [532/3163] OK: Cocodots
# [533/3163] OK: Kokoboard
# [534/3163] OK: Cocoform
# [535/3163] OK: Coconut mosaic panels
# [536/3163] OK: Coconut Tiles
# [537/3163] OK: Cocoon Mesh
# [538/3163] OK: Cocoon
# [539/3163] OK: Cocoontec
# [540/3163] OK: Cocos Insulation
# [541/3163] OK: Cod Leather
# [542/3163] OK: Arabica Black (food safe)
# [543/3163] OK: Coffee Composite 1
# [544/3163] OK: Coffee Composite 2
# [545/3163] OK: Coffee Panels
# [546/3163] OK: Coffee polymer
# [547/3163] OK: Coffee Tile
# [548/3163] OK: Coffee to Burn pellets
# [549/3163] OK: Coffeefrom® Bio
# [550/3163] OK: Coffeefrom® Eco
# [551/3163] OK: Coffeefrom® Strong
# [552/3163] OK: Coffire
# [553/3163] OK: Colback
# [554/3163] OK: ColdBlack
# [555/3163] OK: Coldharbour fishing net tiles
# [556/3163] OK: Collagen Peptide Fabric
# [557/3163] OK: Collection AKOESTIEK
# [558/3163] OK: Collection Glass
# [559/3163] OK: ColorBlast solar panels
# [560/3163] OK: ColorCore® Compact by Formica Group
# [561/3163] OK: ColorCore® by Formica Group
# [562/3163] OK: Colored Rigidized Textures
# [563/3163] OK: Colour Anodized Titanium
# [564/3163] OK: Colour Changing Glass
# [565/3163] OK: Colour changing materials
# [566/3163] OK: Colour Chips Glass
# [567/3163] OK: Colour Line
# [568/3163] OK: Colour Panels
# [569/3163] OK: Coloured Felt
# [570/3163] OK: Coloured Solar panels
# [571/3163] OK: Combisol
# [572/3163] OK: Comfortemp
# [573/3163] OK: Common Sands – Forite
# [574/3163] OK: Compacfoam
# [575/3163] OK: CompacMel Plus
# [576/3163] OK: Compact Panel – Trend
# [577/3163] OK: Compact Tile
# [578/3163] OK: Compensatiesteen
# [579/3163] OK: Completely 100% recylced Polydrop
# [580/3163] OK: Complite
# [581/3163] OK: Compodeen
# [582/3163] OK: Compose handwoven textile
# [583/3163] OK: Composite stone
# [584/3163] OK: Compostboard
# [585/3163] OK: CON-Cover
# [586/3163] OK: CON-Pearl
# [587/3163] OK: Conbou Bamboo
# [588/3163] OK: Concept wood
# [589/3163] OK: Concreate
# [590/3163] OK: Concrete Cloth
# [591/3163] OK: Concrete Crochet Tiles
# [592/3163] OK: Concrete Curtain
# [593/3163] OK: Concrete & Glass
# [594/3163] OK: Concrete Lace
# [595/3163] OK: Concrete-Silicone
# [596/3163] OK: Concrete skin vintage
# [597/3163] OK: Concrete skin
# [598/3163] OK: Concrete wallpaper
# [599/3163] OK: Conductive Stretch Fabric
# [600/3163] OK: Conductive tape
# [601/3163] OK: Conifer needles panels
# [602/3163] OK: Connection Safety Glass
# [603/3163] OK: CONNECTION WALLS
# [604/3163] OK: Conscience fabrics
# [605/3163] OK: Constructive glass
# [606/3163] OK: Contemporary Textiles
# [607/3163] OK: Contender Woven Sailcloth
# [608/3163] OK: Contra-H
# [609/3163] OK: Contract Base
# [610/3163] OK: Contur
# [611/3163] OK: Conturax
# [612/3163] OK: CoolCork
# [613/3163] OK: Cooley-Brite® Lite
# [614/3163] OK: Coolguard™ HR
# [615/3163] OK: CoolJeans
# [616/3163] OK: CoolLeather
# [617/3163] OK: Cooltrax
# [618/3163] OK: Copper and Brass Wire Mesh
# [619/3163] OK: Copper Moss
# [620/3163] OK: Copper Slag Geopolymer
# [621/3163] OK: Copper tiles collection
# [622/3163] OK: Copperant paint
# [623/3163] OK: Coppo
# [624/3163] OK: Coquim coconut fibre
# [625/3163] OK: Corafoam
# [626/3163] OK: Coral & Magic Oak
# [627/3163] OK: Corcrete
# [628/3163] OK: CORDURA combat wool
# [629/3163] OK: Cordura Nyco fabric
# [630/3163] OK: Corduroy
# [631/3163] OK: Coremat
# [632/3163] OK: Corian Nuwood
# [633/3163] OK: Corian Onyx
# [634/3163] OK: Corian Resilience Technology
# [635/3163] OK: Corium bonded leather
# [636/3163] OK: Cork Fabric
# [637/3163] OK: Cork façade
# [638/3163] OK: Cork green roof
# [639/3163] OK: Cork leather
# [640/3163] OK: Cork Leather
# [641/3163] OK: Cork Fabric
# [642/3163] OK: Cork plaster
# [643/3163] OK: CPCs – Cork Polymer Compounds
# [644/3163] OK: Cork rugs
# [645/3163] OK: Cork Spray Paint
# [646/3163] OK: Cork Textile & Surfaces
# [647/3163] OK: Cork Wallpaper
# [648/3163] OK: Cork
# [649/3163] OK: Corkleaf & Corkskin
# [650/3163] OK: CORKonLINEN
# [651/3163] OK: Corktex
# [652/3163] OK: Cornspan
# [653/3163] OK: CornWall
# [654/3163] OK: Corques
# [655/3163] OK: Corten Ceramic Tile
# [656/3163] OK: Cotton Plaster
# [657/3163] OK: Cottone Superbo Conchiglia
# [658/3163] OK: Cottone Superbo Imperatore
# [659/3163] OK: Cottonfloor
# [660/3163] OK: Cottonmix AE panel
# [661/3163] OK: Cottonmix
# [662/3163] OK: Cowpot
# [663/3163] OK: CPC Cork Polymer composite
# [664/3163] OK: Crackle glass
# [665/3163] OK: Crafted Felt
# [666/3163] OK: Crea-Lite
# [667/3163] OK: Creacrete
# [668/3163] OK: CREAMELT® PLA-HI
# [669/3163] OK: CREAMELT® rPET fifty
# [670/3163] OK: Creamelt TPU-R filament
# [671/3163] OK: Creative Copper
# [672/3163] OK: Criaterra wall tiles
# [673/3163] OK: Crinson Wall Tiles
# [674/3163] OK: Crispy
# [675/3163] OK: Cristalite
# [676/3163] OK: Cristallino
# [677/3163] OK: Cristallite
# [678/3163] OK: Crush paper
# [679/3163] OK: Crustic
# [680/3163] OK: Cruz Foam
# [681/3163] OK: CRYLON®
# [682/3163] OK: CRYLUX®
# [683/3163] OK: Crystal Fabric
# [684/3163] OK: Crystal inlay
# [685/3163] OK: Crystal Inlay
# [686/3163] OK: Crystal Mesh & Metal Trimmings
# [687/3163] OK: Crystal Rocks
# [688/3163] OK: Cullus Molto
# [689/3163] OK: Cullus
# [690/3163] OK: Cumbrian Bone Marble
# [691/3163] OK: Cuncha Nasu Shell
# [692/3163] OK: Curious
# [693/3163] OK: Curv
# [694/3163] OK: CurvCor
# [695/3163] OK: Curved Panels
# [696/3163] OK: Custom Shaped Stainless Steel
# [697/3163] OK: 3D printed customised composites
# [698/3163] OK: Customised Wallpaper Collection
# [699/3163] OK: CUSTOMIZE
# [700/3163] OK: Cutting-Edge
# [701/3163] OK: Cyalith
# [702/3163] OK: Cyclin®
# [703/3163] OK: D-Carb White cement
# [704/3163] OK: D-ko expanded metal
# [705/3163] OK: D-sign weave
# [706/3163] OK: D2W
# [707/3163] OK: d3o mesh
# [708/3163] OK: Dacryl
# [709/3163] OK: Daemwool natural wool insulation
# [710/3163] OK: Dakota Burl
# [711/3163] OK: Dalsouple
# [712/3163] OK: Damasco
# [713/3163] OK: Dapple Smile Plastics
# [714/3163] OK: Daylight panels
# [715/3163] OK: Déchirer
# [716/3163] OK: Decafé
# [717/3163] OK: Decalised glass
# [718/3163] OK: Decallisation
# [719/3163] OK: Decking solutions
# [720/3163] OK: DecNord Luxpanels
# [721/3163] OK: Deco S
# [722/3163] OK: Deco Wired Glass
# [723/3163] OK: DecoLegno HPL Specials
# [724/3163] OK: DECOPROYEC SPRAY CORK
# [725/3163] OK: Decoral Process
# [726/3163] OK: Decorandum
# [727/3163] OK: Decorated Metal Mesh
# [728/3163] OK: Decorex
# [729/3163] OK: DecorFlou
# [730/3163] OK: DecorGem
# [731/3163] OK: Decoro
# [732/3163] OK: Decortile
# [733/3163] OK: DEEP 3D Wallpaper
# [734/3163] OK: Deep Sea
# [735/3163] OK: Defense
# [736/3163] OK: Dega Art
# [737/3163] OK: Dejection-molding
# [738/3163] OK: Dekoart
# [739/3163] OK: Dekolux Fossil
# [740/3163] OK: Dekolux
# [741/3163] OK: Dekopix
# [742/3163] OK: Dekorial
# [743/3163] OK: Dekovario
# [744/3163] OK: Dekton Industrial recycled
# [745/3163] OK: Demidekk Ultimate Helmatt
# [746/3163] OK: Demidekk Ultimate Täckfärg
# [747/3163] OK: DendroLight Building Block (BB)
# [748/3163] OK: DendroLight core material
# [749/3163] OK: DendroLight Table Tops
# [750/3163] OK: Denimolite
# [751/3163] OK: DenimX Material Collection
# [752/3163] OK: Denimx
# [753/3163] OK: Denuo
# [754/3163] OK: Derbipure
# [755/3163] OK: Derbisolar
# [756/3163] OK: Dermofresh FR
# [757/3163] OK: DESARDI Classic Non-Woven
# [758/3163] OK: Desert Dunes
# [759/3163] OK: Design-Aero
# [760/3163] OK: Design Coconut Tiles
# [761/3163] OK: Design concrete
# [762/3163] OK: Design Felt
# [763/3163] OK: Design induction hobs
# [764/3163] OK: Design Panel
# [765/3163] OK: Design Sheets
# [766/3163] OK: Designers Collection
# [767/3163] OK: Desserto® cactus leather
# [768/3163] OK: Dexter
# [769/3163] OK: DG-Lux Plus
# [770/3163] OK: Diamond Board
# [771/3163] OK: Diamond Polished Concrete
# [772/3163] OK: DIBOND®
# [773/3163] OK: Dichrolam
# [774/3163] OK: Diggels
# [775/3163] OK: Digital Dawn
# [776/3163] OK: DigitalPrint – Serie Metalli
# [777/3163] OK: Dinamica Classica
# [778/3163] OK: Dinxperlo
# [779/3163] OK: Dipline
# [780/3163] OK: Direx
# [781/3163] OK: Discarded Firehose
# [782/3163] OK: Discarded tampon fabric
# [783/3163] OK: DISPA®
# [784/3163] OK: Dissolvo
# [785/3163] OK: Ditra 25
# [786/3163] OK: Divine (Dischroic) Tiles
# [787/3163] OK: Division & Growth glass tiles
# [788/3163] OK: Dofine stucco
# [789/3163] OK: Doluflex
# [790/3163] OK: Domino
# [791/3163] OK: Domsteen brick
# [792/3163] OK: DORSUM®
# [793/3163] OK: Doschawol
# [794/3163] OK: Dot concrete
# [795/3163] OK: Dot Show
# [796/3163] OK: Double Face
# [797/3163] OK: Double Vision Composition
# [798/3163] OK: Drapilux Air
# [799/3163] OK: Drapilux Bioaktiv
# [800/3163] OK: Dream bonding technology
# [801/3163] OK: Dreamfield
# [802/3163] OK: Dreamglass
# [803/3163] OK: Dreamshape
# [804/3163] OK: Dredged sediment concrete
# [805/3163] OK: DreenDesign Collection
# [806/3163] OK: Drenth Metal Weaving
# [807/3163] OK: Drenth Plastic Weaving
# [808/3163] OK: Dripping
# [809/3163] OK: Drop Papers
# [810/3163] OK: Drop Stich Fabrics
# [811/3163] OK: Droplet
# [812/3163] OK: Droptec
# [813/3163] OK: DRT Special Items
# [814/3163] OK: Bio-Thermoplastic elastomer
# [815/3163] OK: Drystack brick system
# [816/3163] OK: Dual Stencil Process
# [817/3163] OK: Ductal
# [818/3163] OK: DuFLEX lightweight panels
# [819/3163] OK: Duho-Tex
# [820/3163] OK: Dukta Flexible Wood
# [821/3163] OK: Duotec
# [822/3163] OK: Duotone Coloured Glass
# [823/3163] OK: Duplicor® biobased composite
# [824/3163] OK: Durabella Palladiana
# [825/3163] OK: DURABELLA seamless terrazzo
# [826/3163] OK: Durabella x Aectual
# [827/3163] OK: DuraBook
# [828/3163] OK: Duralmond
# [829/3163] OK: Duramique mineral flooring
# [830/3163] OK: Durapor & Duraseal
# [831/3163] OK: DuraPulp
# [832/3163] OK: Durapur
# [833/3163] OK: Duraskin
# [834/3163] OK: Durasteel
# [835/3163] OK: Durastone Flexible Polished Floors
# [836/3163] OK: Durat Palace
# [837/3163] OK: Durat®
# [838/3163] OK: Duro loam plaster
# [839/3163] OK: Durodeen
# [840/3163] OK: DuroGrit
# [841/3163] OK: Duropal HPL
# [842/3163] OK: Duropal
# [843/3163] OK: Durum
# [844/3163] OK: Dutch Merino
# [845/3163] OK: Dutch Mohair
# [846/3163] OK: Dutch Patine
# [847/3163] OK: Dutch Wool
# [848/3163] OK: Dyed Polyester Fancy Hairy
# [849/3163] OK: Dyed Polyester Jacquard Structure
# [850/3163] OK: Dyed Polyester Sheer Lace
# [851/3163] OK: DynamicWall
# [852/3163] OK: E-GLAS
# [853/3163] OK: Eastar copolyester 6763
# [854/3163] OK: Easy Being Green
# [855/3163] OK: Ebablock
# [856/3163] OK: Ebb
# [857/3163] OK: ECC
# [858/3163] OK: Ecdel
# [859/3163] OK: EchoPanel
# [860/3163] OK: ECI Ceramic Coating
# [861/3163] OK: Eco-brick
# [862/3163] OK: Eco-c1
# [863/3163] OK: Eco-Cem
# [864/3163] OK: Eco-Green
# [865/3163] OK: Eco-Gres
# [866/3163] OK: ECO-HPL
# [867/3163] OK: Eco Range
# [868/3163] OK: Eco Series Wall Panels
# [869/3163] OK: Feutralin
# [870/3163] OK: Eco-Terr
# [871/3163] OK: Eco X extreme concrete
# [872/3163] OK: Eco
# [873/3163] OK: Ecoben
# [874/3163] OK: ECOBoard
# [875/3163] OK: Ecobrass
# [876/3163] OK: ecoHAB
# [877/3163] OK: Ecolan® recycled solid surface
# [878/3163] OK: EcoLine Brick Slips
# [879/3163] OK: ecologia Fluido
# [880/3163] OK: ecologia Marmo
# [881/3163] OK: ecologia Transeco
# [882/3163] OK: Ecolution recycled nylon fabric
# [883/3163] OK: EconCore 100% bio-based
# [884/3163] OK: EconCore Honeycomb
# [885/3163] OK: Econcrete
# [886/3163] OK: Econic
# [887/3163] OK: econitWood
# [888/3163] OK: Ecopan
# [889/3163] OK: EcoPaxx
# [890/3163] OK: Ecopixel
# [891/3163] OK: Ecoplex
# [892/3163] OK: WavCor ESP
# [893/3163] OK: Ecosurfaces
# [894/3163] OK: ECOwall with recycled PET & polyester
# [895/3163] OK: ECOwall with wool
# [896/3163] OK: EcoWorx tile
# [897/3163] OK: Edgemax
# [898/3163] OK: Eelgrass Acoustic Mats
# [899/3163] OK: EEUWENHOUT
# [900/3163] OK: Effect Glass
# [901/3163] OK: Effect Varnish
# [902/3163] OK: EG Wall Panels
# [903/3163] OK: Ege CircleBack
# [904/3163] OK: Egg bioplastic
# [905/3163] OK: Eggshell-based ceramics and bioplastics
# [906/3163] OK: Eggshell Ceramic
# [907/3163] OK: Eggshell inlay
# [908/3163] OK: Eggware
# [909/3163] OK: Ekoa®
# [910/3163] OK: Ekogrip / Colourgrip
# [911/3163] OK: EKOlithos board
# [912/3163] OK: Ekotex Clean Air (Schone Lucht)
# [913/3163] OK: Ekotex Hygiene
# [914/3163] OK: Ekotex Magnet Whiteboard
# [915/3163] OK: EKOTEX Opposites
# [916/3163] OK: Ekovilla Cellulose Insulation Slab
# [917/3163] OK: Elastic Conductive Tape
# [918/3163] OK: Elastolite
# [919/3163] OK: ElceeStone
# [920/3163] OK: Electric Plaid
# [921/3163] OK: Electrical Heating Textile
# [922/3163] OK: Electroluminescent Panel
# [923/3163] OK: Electroluminescent textiles
# [924/3163] OK: Electroluminescent Wire
# [925/3163] OK: Electrolycra
# [926/3163] OK: Electronylon
# [927/3163] OK: Elements
# [928/3163] OK: Elite Lava
# [929/3163] OK: Ellisse
# [930/3163] OK: eLM Zero
# [931/3163] OK: Eltec
# [932/3163] OK: Embossed Leather
# [933/3163] OK: Embossed Leather
# [934/3163] OK: Embossed leather
# [935/3163] OK: Embossed printed canvas
# [936/3163] OK: Embrace
# [937/3163] OK: Embroidered Wool
# [938/3163] OK: Emotex
# [939/3163] OK: Enameled Steel
# [940/3163] OK: End Grain Veneer
# [941/3163] OK: Endless life
# [942/3163] OK: Engobed brick
# [943/3163] OK: Enkagrid
# [944/3163] OK: Enkair
# [945/3163] OK: Environ Biocomposite
# [946/3163] OK: Environmental Tulle and Power Nets
# [947/3163] OK: EPDM Membrane
# [948/3163] OK: Equitone Linea
# [949/3163] OK: Equitone materia
# [950/3163] OK: Equitone Natura
# [951/3163] OK: Equitone Pictura
# [952/3163] OK: Equitone Tectiva
# [953/3163] OK: Erlus Titan-silver
# [954/3163] OK: Esb Plus elka strong board
# [955/3163] OK: ESD Static Fabric
# [956/3163] OK: Esia Natura Wood
# [957/3163] OK: Esprit Nouveau
# [958/3163] OK: Essemplex
# [959/3163] OK: Essential Texture
# [960/3163] OK: Essentials Metal-art
# [961/3163] OK: Essentials wood
# [962/3163] OK: EtaProof
# [963/3163] OK: Eterno Unico, Chrono & Terrazzo
# [964/3163] OK: ETFE Colour
# [965/3163] OK: ETNA
# [966/3163] OK: Ettlin Lux & Tec
# [967/3163] OK: euca wood
# [968/3163] OK: Eucalyptus cloeziana timber
# [969/3163] OK: Eucalyptus grandis Cross Laminated Timber (CLT)
# [970/3163] OK: Eurodekor
# [971/3163] OK: EuroLight
# [972/3163] OK: EUROPLEX O
# [973/3163] OK: EUROPLEX PPSU
# [974/3163] OK: Evalon Solar
# [975/3163] OK: Evans & Brown Wallcoverings
# [976/3163] OK: Ever Air Pass
# [977/3163] OK: Ever Dye
# [978/3163] OK: Ever Light Rainwear
# [979/3163] OK: Ever Visible
# [980/3163] OK: Evergreen
# [981/3163] OK: Everroll
# [982/3163] OK: EvoHide™ Mistral
# [983/3163] OK: Ex-Static
# [984/3163] OK: Exciton Collection
# [985/3163] OK: Exclusive 1015 flooring
# [986/3163] OK: EXIE fibres
# [987/3163] OK: MicroFibrillated Cellulose
# [988/3163] OK: ExoGrid
# [989/3163] OK: Expanded Cork Cocos Isolation
# [990/3163] OK: Expanded Cork Isolation
# [991/3163] OK: Expanded Meshes
# [992/3163] OK: Expanded metal mesh
# [993/3163] OK: Expanded Polypropylene
# [994/3163] OK: Expanded Silicone rubber
# [995/3163] OK: Experience Wood in Faced Panels
# [996/3163] OK: Experimental Terrazzo
# [997/3163] OK: Experimental textile design
# [998/3163] OK: Exploform
# [999/3163] OK: Explore Metals Jet
# [1000/3163] OK: Extrema
# [1001/3163] OK: Extruded aluminium panels
# [1002/3163] OK: Ezobord
# [1003/3163] OK: Faay
# [1004/3163] OK: FABBACK Colored Acrylic Mirror
# [1005/3163] OK: Fabcell
# [1006/3163] OK: Fabraa recycled upholstery fabric
# [1007/3163] OK: Fabraa Reproper Upholstery Fabrics
# [1008/3163] OK: Fabulous Fungi dye
# [1009/3163] OK: Fair trade handwoven rug
# [1010/3163] OK: Fake boa leather
# [1011/3163] OK: Falcon Glass
# [1012/3163] OK: Fame
# [1013/3163] OK: Fantastic Bioplastic
# [1014/3163] OK: Far Out Lace
# [1015/3163] OK: Fashionable Sheers
# [1016/3163] OK: Fassade
# [1017/3163] OK: Fassawall
# [1018/3163] OK: FatPad
# [1019/3163] OK: FaunaWood
# [1020/3163] OK: Faux fur
# [1021/3163] OK: Fauxteak
# [1022/3163] OK: Feathered Fabrics
# [1023/3163] OK: Febrik Textiles
# [1024/3163] OK: FeelingWood wood fibre insulation
# [1025/3163] OK: FEKE
# [1026/3163] OK: Felice handwoven carpet
# [1027/3163] OK: Felt for Architecture
# [1028/3163] OK: Felt textiles
# [1029/3163] OK: Felt
# [1030/3163] OK: Feltro Legno
# [1031/3163] OK: FENIX NTA
# [1032/3163] OK: FENIX NTM BLOOM & ARPA HPL BLOOM
# [1033/3163] OK: FENIX NTM BLOOM
# [1034/3163] OK: Fenix NTM (Nano Tech Matt)
# [1035/3163] OK: fermacell® floor elements
# [1036/3163] OK: Ferricon
# [1037/3163] OK: FF2
# [1038/3163] OK: FFEXX liquid flooring
# [1039/3163] OK: Fiamma
# [1040/3163] OK: Fibernyl
# [1041/3163] OK: Fiberstone
# [1042/3163] OK: Fibracolour TEX
# [1043/3163] OK: Fibralux biobased
# [1044/3163] OK: Fibranatur TEX
# [1045/3163] OK: Fibre C
# [1046/3163] OK: FibreForm
# [1047/3163] OK: FibreLite
# [1048/3163] OK: FibreStrap – the Sustainable Cable Tie
# [1049/3163] OK: Fibrimat
# [1050/3163] OK: Fibrolon
# [1051/3163] OK: Field
# [1052/3163] OK: FieldTurf
# [1053/3163] OK: Fielitz
# [1054/3163] OK: Fileo
# [1055/3163] OK: FILIE® Foam
# [1056/3163] OK: FILIE®
# [1057/3163] OK: FilzFelt
# [1058/3163] OK: Fineline Panel
# [1059/3163] OK: Fineo vacuum insulating glass
# [1060/3163] OK: Finett Dimension
# [1061/3163] OK: Finex 3D
# [1062/3163] OK: Finiglas
# [1063/3163] OK: Finti
# [1064/3163] OK: Fire retardant coating system (exterior)
# [1065/3163] OK: Fire retardant coating system (interior)
# [1066/3163] OK: Firetight®-Firetape
# [1067/3163] OK: First Circular Insulation
# [1068/3163] OK: Fiscagomma
# [1069/3163] OK: Bricola collection
# [1070/3163] OK: Fishy Filaments
# [1071/3163] OK: Fixcrete
# [1072/3163] OK: Flameprotect Compact
# [1073/3163] OK: Flamexx
# [1074/3163] OK: Flamline decorative non-flammable fabrics
# [1075/3163] OK: Flaster Tiles
# [1076/3163] OK: FlatCor
# [1077/3163] OK: Flax Oil Paint
# [1078/3163] OK: Flax-reinforced composite materials
# [1079/3163] OK: Flax wall core
# [1080/3163] OK: Flax wallpaper
# [1081/3163] OK: Flax
# [1082/3163] OK: Flaxco flax composite
# [1083/3163] OK: Flaxcomposites
# [1084/3163] OK: Flaxline
# [1085/3163] OK: FlaxTape
# [1086/3163] OK: Fleece ’n ’Flex
# [1087/3163] OK: Flex-Plain CS S-2003
# [1088/3163] OK: Flex-Plain CS S-2004
# [1089/3163] OK: Flex-Plain CS Typ 03
# [1090/3163] OK: Flex
# [1091/3163] OK: Flexene
# [1092/3163] OK: Flexglass Decor
# [1093/3163] OK: Flexible Sandstone
# [1094/3163] OK: Flexible Wood Covering
# [1095/3163] OK: Flexint
# [1096/3163] OK: Flexipan
# [1097/3163] OK: FlexSandStone
# [1098/3163] OK: Flexwood
# [1099/3163] OK: Flexzorb activated carbon cloth
# [1100/3163] OK: Floating Nature collage
# [1101/3163] OK: Flock
# [1102/3163] OK: Flocked with textile
# [1103/3163] OK: Flocus kapok fleece
# [1104/3163] OK: Flood
# [1105/3163] OK: Flosing glass
# [1106/3163] OK: Flotex Vision
# [1107/3163] OK: Flow
# [1108/3163] OK: Flower Massionite
# [1109/3163] OK: Flower Power wall paint
# [1110/3163] OK: Flowing Art
# [1111/3163] OK: Flowstone
# [1112/3163] OK: Fluor Band
# [1113/3163] OK: Fluxus
# [1114/3163] OK: foam Andrea Valentini
# [1115/3163] OK: Foam Inventions
# [1116/3163] OK: Foam Railing
# [1117/3163] OK: FOAMALITE®
# [1118/3163] OK: Foamglas
# [1119/3163] OK: Foglizzo Folds
# [1120/3163] OK: Foldcore
# [1121/3163] OK: Folded Concrete
# [1122/3163] OK: Folding A-Part
# [1123/3163] OK: Foldtex
# [1124/3163] OK: Food Waste Pigment
# [1125/3163] OK: Foodmeshes
# [1126/3163] OK: For Greener Pastures
# [1127/3163] OK: For the sea
# [1128/3163] OK: Force wallpaper
# [1129/3163] OK: Forestlines®
# [1130/3163] OK: FOREX®
# [1131/3163] OK: Forj Thermoplastic Tape-Ribbon
# [1132/3163] OK: Formcard
# [1133/3163] OK: ForMetal Varius
# [1134/3163] OK: Formica® Color Laminates
# [1135/3163] OK: Formica® Doors Collection
# [1136/3163] OK: Formica® Washroom Collection
# [1137/3163] OK: Fortis Arbor Wood Mosaics
# [1138/3163] OK: Forza recycled fabric
# [1139/3163] OK: ForzGlaze
# [1140/3163] OK: found space tiles
# [1141/3163] OK: Fractal Aluminium sheets
# [1142/3163] OK: Fractalis Effect Paints
# [1143/3163] OK: Fractalis Glass collection
# [1144/3163] OK: Fragments of the Past
# [1145/3163] OK: Fraké Noir
# [1146/3163] OK: Framax laser cutting technology
# [1147/3163] OK: Framilon
# [1148/3163] OK: Freek Outdoor Carpet
# [1149/3163] OK: Freestile Venice
# [1150/3163] OK: Fringe fabric
# [1151/3163] OK: From Ash
# [1152/3163] OK: From banknotes to textiles
# [1153/3163] OK: From Insects: Wooden Leather
# [1154/3163] OK: From Stone to Glass
# [1155/3163] OK: From the Underground tiles
# [1156/3163] OK: Fruit & veggie paper
# [1157/3163] OK: Fruits
# [1158/3163] OK: Fruitwood
# [1159/3163] OK: Frumo
# [1160/3163] OK: Fucina
# [1161/3163] OK: Fujifu wisteria fabric
# [1162/3163] OK: Fun Fur New
# [1163/3163] OK: Fun Fur
# [1164/3163] OK: Fungi Force
# [1165/3163] OK: FUR concrete wall tile
# [1166/3163] OK: Fused glass
# [1167/3163] OK: Fusion Metal
# [1168/3163] OK: Fusion Wood Panels
# [1169/3163] OK: FuturePrint
# [1170/3163] OK: Fuzioglas
# [1171/3163] OK: FytoPanel
# [1172/3163] OK: G.tecz Floral Print
# [1173/3163] OK: Gagecast
# [1174/3163] OK: Galaxy
# [1175/3163] OK: Galaxy
# [1176/3163] OK: Gama Duo Collection 2020-2022
# [1177/3163] OK: Gama Duo Nude Texture
# [1178/3163] OK: Garmento Boards
# [1179/3163] OK: Gaudenzi
# [1180/3163] OK: GECKO adhesive textile
# [1181/3163] OK: Gel Pal
# [1182/3163] OK: Gelatine Bioplastic
# [1183/3163] OK: Geni-us
# [1184/3163] OK: Geo Slate
# [1185/3163] OK: Geocell Glass foam
# [1186/3163] OK: Geocomposite geogrid-geotextile
# [1187/3163] OK: Geodesia
# [1188/3163] OK: Geofil-Bubbles
# [1189/3163] OK: Geology
# [1190/3163] OK: Georiflessi
# [1191/3163] OK: GeoStylistix Stone Strips
# [1192/3163] OK: GetaCore solid surface
# [1193/3163] OK: Giant Hogweed wallpanels
# [1194/3163] OK: GIRIA Tree bark biocomposite
# [1195/3163] OK: GKD Crystal
# [1196/3163] OK: GKD
# [1197/3163] OK: Glacier and Honeycomb glass
# [1198/3163] OK: Glam-Glass panels
# [1199/3163] OK: Glamé
# [1200/3163] OK: Glamorous leather
# [1201/3163] OK: Glamour
# [1202/3163] OK: Glare
# [1203/3163] OK: Glasio acoustic glass
# [1204/3163] OK: Glass Beads
# [1205/3163] OK: Glass block
# [1206/3163] OK: Glass brick by Poesia
# [1207/3163] OK: Glass Brick
# [1208/3163] OK: Glass Colors
# [1209/3163] OK: Glass Foam
# [1210/3163] OK: Glass full colour
# [1211/3163] OK: Glass Inspiration
# [1212/3163] OK: Glass mosaic
# [1213/3163] OK: Glass Polymer
# [1214/3163] OK: Glass with Shells
# [1215/3163] OK: Glass2
# [1216/3163] OK: Glass2Style
# [1217/3163] OK: Glassiled
# [1218/3163] OK: Glassique
# [1219/3163] OK: GlassKote
# [1220/3163] OK: Glassworks
# [1221/3163] OK: GLASSX crystal
# [1222/3163] OK: Glazed Ceramic Iridescent
# [1223/3163] OK: Glazed Ceramics in Various Blue
# [1224/3163] OK: Glitter
# [1225/3163] OK: Global Collection and Mosa Colors
# [1226/3163] OK: Globo-X
# [1227/3163] OK: Glossop & Girmo fabric
# [1228/3163] OK: Glow-in-the-dark coatings
# [1229/3163] OK: Glow In the Dark
# [1230/3163] OK: Glowway
# [1231/3163] OK: Gluetex Biovate Wallcovering
# [1232/3163] OK: Gold Mosaic
# [1233/3163] OK: Golden Tile
# [1234/3163] OK: Golf Romeo small
# [1235/3163] OK: GoodCatch
# [1236/3163] OK: Gounda fabric
# [1237/3163] OK: Govaplast
# [1238/3163] OK: Gradient
# [1239/3163] OK: Graepel
# [1240/3163] OK: Gramitherm®
# [1241/3163] OK: Limas Mango Grand Pyramid
# [1242/3163] OK: Grandezza Antique brass
# [1243/3163] OK: Grandezza Corten steel
# [1244/3163] OK: Grandezza Seamless Metal-Effect Coating
# [1245/3163] OK: Granite Deep Mat
# [1246/3163] OK: Granite Quartz
# [1247/3163] OK: Granite Silky Shine
# [1248/3163] OK: Granite
# [1249/3163] OK: AmbientPro+ graphene paint
# [1250/3163] OK: Graphic Concrete
# [1251/3163] OK: Graphic Relief – Photographic Detail
# [1252/3163] OK: Graphic Relief
# [1253/3163] OK: Graphical Facade Coating
# [1254/3163] OK: Grass & Leaves
# [1255/3163] OK: Grass rug
# [1256/3163] OK: Gravel Floor
# [1257/3163] OK: Gravity Mosaic
# [1258/3163] OK: Green Blade veneer
# [1259/3163] OK: Green Cast®
# [1260/3163] OK: Green Panel
# [1261/3163] OK: Greenful Panel
# [1262/3163] OK: #GREENGRIDZ
# [1263/3163] OK: Greenpanel Negro
# [1264/3163] OK: greenSand
# [1265/3163] OK: Greensulate
# [1266/3163] OK: Grei line
# [1267/3163] OK: Grey MDF – Fibracolour Gris
# [1268/3163] OK: GRIP Metal
# [1269/3163] OK: GRP Profiles
# [1270/3163] OK: Gum-tec®
# [1271/3163] OK: Gyproc A plasterboard
# [1272/3163] OK: H-bite Sailcloth
# [1273/3163] OK: H13/013
# [1274/3163] OK: Haava & Uni
# [1275/3163] OK: Habitus Cork Mosaic
# [1276/3163] OK: Hairexcel® – 60
# [1277/3163] OK: Hairy
# [1278/3163] OK: Halusite
# [1279/3163] OK: HAND CRAFTED LIME PLASTER
# [1280/3163] OK: Hand loomed leather & silk
# [1281/3163] OK: Hand-marbled fabrics
# [1282/3163] OK: Hand woven Fabric
# [1283/3163] OK: Handmade elephant dung paper
# [1284/3163] OK: HANDMADE NATURAL RUGS
# [1285/3163] OK: Haptic 2.5D printing
# [1286/3163] OK: HaRiMex tube
# [1287/3163] OK: Havvalon
# [1288/3163] OK: Haze
# [1289/3163] OK: Healthcare & transportation fabrics
# [1290/3163] OK: HeartFelt
# [1291/3163] OK: Heat Treated Carpet
# [1292/3163] OK: Heated fabric
# [1293/3163] OK: Heath Tiles
# [1294/3163] OK: Piezoelectric Haptic Actuator
# [1295/3163] OK: HelenAmyMurray
# [1296/3163] OK: Helicone HC
# [1297/3163] OK: Hemp concrete
# [1298/3163] OK: Hemp fiber nonwoven mats
# [1299/3163] OK: Hemp fur
# [1300/3163] OK: Hemp insulation
# [1301/3163] OK: Hemp panels
# [1302/3163] OK: Hemp Shag
# [1303/3163] OK: Hemp
# [1304/3163] OK: HempFlax Nature Insulation
# [1305/3163] OK: Hempstatic®
# [1306/3163] OK: HempWood® Natural Flooring
# [1307/3163] OK: Hévé textile
# [1308/3163] OK: Hexaben
# [1309/3163] OK: Hexal
# [1310/3163] OK: Hey Jute fabric
# [1311/3163] OK: Heytex Sign
# [1312/3163] OK: HI-MACS Nederland
# [1313/3163] OK: Hiendl NFC
# [1314/3163] OK: High Gloss Poured Surfaces
# [1315/3163] OK: High-Tech Stone
# [1316/3163] OK: Himalayan Salt Block
# [1317/3163] OK: Himalayan Salt
# [1318/3163] OK: HIPEX®
# [1319/3163] OK: Historical Tiles
# [1320/3163] OK: Hollandfelt Wool felt
# [1321/3163] OK: HoloPro
# [1322/3163] OK: HoloSign
# [1323/3163] OK: HolyPan Finished
# [1324/3163] OK: HolyPan Composite
# [1325/3163] OK: Holz in Form relief panel
# [1326/3163] OK: Holz100
# [1327/3163] OK: Homastone
# [1328/3163] OK: HONEXT® Panel
# [1329/3163] OK: Honeycomb core
# [1330/3163] OK: Honeycomb Paper Board
# [1331/3163] OK: Honeycomb
# [1332/3163] OK: Horsehair Weaving
# [1333/3163] OK: Hot Stamping Foils
# [1334/3163] OK: HOTwood essen Uni line
# [1335/3163] OK: HP Nylon Plastic
# [1336/3163] OK: HPL and HPL veneer full colour
# [1337/3163] OK: HSB Bioboards
# [1338/3163] OK: HT coating for ceramic tiles
# [1339/3163] OK: Hugging Clayrolls
# [1340/3163] OK: Huguet recycled terrazzo
# [1341/3163] OK: Human hair rope
# [1342/3163] OK: Husk
# [1343/3163] OK: Husque
# [1344/3163] OK: Hybrid collection
# [1345/3163] OK: Hybrid insulation
# [1346/3163] OK: Hybrix Flexible
# [1347/3163] OK: Hybrix
# [1348/3163] OK: Hydro Chromic White
# [1349/3163] OK: Hydro sustainable aluminium
# [1350/3163] OK: Hydrophobic & Oleophobic Coatings
# [1351/3163] OK: Hygroscopic Mortar
# [1352/3163] OK: Hyper Wood
# [1353/3163] OK: Hyperion wood composite
# [1354/3163] OK: Hyperrealistic concrete
# [1355/3163] OK: Hyperwave
# [1356/3163] OK: I Frammenti
# [1357/3163] OK: I Glassati
# [1358/3163] OK: i.light
# [1359/3163] OK: I-Mesh
# [1360/3163] OK: IAS Wasted Paper
# [1361/3163] OK: Ibena Technodeco
# [1362/3163] OK: Ice Cubes
# [1363/3163] OK: Ice Lighting
# [1364/3163] OK: Iced Barn and Frosted Barn
# [1365/3163] OK: iCell Skiva
# [1366/3163] OK: IceStone
# [1367/3163] OK: Iconic Panels
# [1368/3163] OK: IDEApaint
# [1369/3163] OK: IDUN
# [1370/3163] OK: IGP-DURA®mix
# [1371/3163] OK: IGP-DURA®xal
# [1372/3163] OK: Illuminated Textiles
# [1373/3163] OK: Illumination Panels
# [1374/3163] OK: Ilum
# [1375/3163] OK: Imagic Weave
# [1376/3163] OK: Imagine / Vibe
# [1377/3163] OK: IMAR Singular Metal Solutions
# [1378/3163] OK: Imaz
# [1379/3163] OK: IMI-Altholz
# [1380/3163] OK: Imi-beton (concrete)
# [1381/3163] OK: Imi-rost
# [1382/3163] OK: Imibeton
# [1383/3163] OK: Immersion
# [1384/3163] OK: Imperfection
# [1385/3163] OK: IMPEX®
# [1386/3163] OK: RECYCLED CURTAIN VIGO
# [1387/3163] OK: In-fusion embossed
# [1388/3163] OK: Inax Lascaux
# [1389/3163] OK: Inax Luster color
# [1390/3163] OK: Inax Sentousai
# [1391/3163] OK: Inbusta
# [1392/3163] OK: Inconspicuous Matter
# [1393/3163] OK: Incubo
# [1394/3163] OK: Indigo leather
# [1395/3163] OK: Inducon
# [1396/3163] OK: Indupoint
# [1397/3163] OK: Industrial Craft
# [1398/3163] OK: Hemp & Mycelium Sandwich Panel
# [1399/3163] OK: Industrial Micro Systems
# [1400/3163] OK: Industrial Textiles
# [1401/3163] OK: Inflatable wood
# [1402/3163] OK: Ingeo
# [1403/3163] OK: Inner Skins
# [1404/3163] OK: INNO-X
# [1405/3163] OK: Inorganic Polymer Concrete
# [1406/3163] OK: Inox spectral coloured
# [1407/3163] OK: Inox Tile
# [1408/3163] OK: Inoxtile
# [1409/3163] OK: Insulated Glassblock
# [1410/3163] OK: Insulation with ECOSE Technology
# [1411/3163] OK: Intaglio embossed lampshade material
# [1412/3163] OK: Intelligent sun shading glass
# [1413/3163] OK: Interactive Sensory Design Applicate 0.5
# [1414/3163] OK: Interactive Sensory Design Applicate 1
# [1415/3163] OK: Interwoven
# [1416/3163] OK: Intexmo Wallart
# [1417/3163] OK: InvariLux
# [1418/3163] OK: InvariMatte Walnut
# [1419/3163] OK: Invision
# [1420/3163] OK: Ipachrome design
# [1421/3163] OK: IPC
# [1422/3163] OK: iQ PRO Custom
# [1423/3163] OK: IR Relief
# [1424/3163] OK: Iron Corten
# [1425/3163] OK: Iscreen
# [1426/3163] OK: Iso-Cork
# [1427/3163] OK: Isoflam
# [1428/3163] OK: Isoglas
# [1429/3163] OK: Isolcell and Isolkenaf
# [1430/3163] OK: Isolgomma
# [1431/3163] OK: Istrenn
# [1432/3163] OK: Iznik Print
# [1433/3163] OK: Iznik Full Colour Tiles
# [1434/3163] OK: Jacquard Denim
# [1435/3163] OK: Jacquard Lancé-Découpé
# [1436/3163] OK: Jacquard mesh
# [1437/3163] OK: Jacquard with Metal/Lurex
# [1438/3163] OK: Japanel
# [1439/3163] OK: Japanese knotweed material
# [1440/3163] OK: JB Glass Edition
# [1441/3163] OK: Jelly Tiles
# [1442/3163] OK: Jersey riga fuxia + lurex
# [1443/3163] OK: Jesmonite composite
# [1444/3163] OK: JEWEL BRICK – Knit brick
# [1445/3163] OK: JEWEL BRICK – Storm
# [1446/3163] OK: Jewel
# [1447/3163] OK: Jolie
# [1448/3163] OK: Jotun powder coating
# [1449/3163] OK: JRC REFLEX
# [1450/3163] OK: JUHLA – pine needle textile
# [1451/3163] OK: Juicyglass
# [1452/3163] OK: Jungle
# [1453/3163] OK: Jute Wall tiles
# [1454/3163] OK: K-bench
# [1455/3163] OK: K-Briq
# [1456/3163] OK: Kabekobo Shikkui Plaster
# [1457/3163] OK: Kairatin
# [1458/3163] OK: Kalesinterflex
# [1459/3163] OK: KAPA®
# [1460/3163] OK: Kappa
# [1461/3163] OK: Kareline
# [1462/3163] OK: Karma
# [1463/3163] OK: Karta-pack Bagasse
# [1464/3163] OK: Karta-Pack bagasse-cotton mix
# [1465/3163] OK: Karta-Pack Bamboo
# [1466/3163] OK: Karuun
# [1467/3163] OK: Kaumera
# [1468/3163] OK: Kauri
# [1469/3163] OK: Kaurit® Light technology
# [1470/3163] OK: Kayar
# [1471/3163] OK: Kaynemaile architectural Mesh
# [1472/3163] OK: Kebony Character
# [1473/3163] OK: Kebony Clear
# [1474/3163] OK: Kedroplast
# [1475/3163] OK: KEIM Lignosil-Verano
# [1476/3163] OK: Kenetix Spacer
# [1477/3163] OK: Kepla-coat
# [1478/3163] OK: KerAion
# [1479/3163] OK: Keralpor
# [1480/3163] OK: Kerama facade cladding
# [1481/3163] OK: KeraTwin
# [1482/3163] OK: KERLOC
# [1483/3163] OK: Kerrigan Architectural Tile
# [1484/3163] OK: Kerto Laminated Veneer Lumber
# [1485/3163] OK: Kevlar
# [1486/3163] OK: Ki-Kern
# [1487/3163] OK: Ki-ori Tennâge
# [1488/3163] OK: Kilkenny
# [1489/3163] OK: Kiln cast glass
# [1490/3163] OK: Kilolux Glass
# [1491/3163] OK: King W
# [1492/3163] OK: Kingskin
# [1493/3163] OK: Kintyre
# [1494/3163] OK: Kirei Board
# [1495/3163] OK: Kisho
# [1496/3163] OK: Klimatec
# [1497/3163] OK: KLP-Greenmatter
# [1498/3163] OK: KLP Recycled Panels
# [1499/3163] OK: 3d textiles knitted and woven
# [1500/3163] OK: Knitted steel fabric
# [1501/3163] OK: Knitted Walls
# [1502/3163] OK: KNOFtex
# [1503/3163] OK: Knotty
# [1504/3163] OK: KNOxOUT
# [1505/3163] OK: Ko-Bol
# [1506/3163] OK: KO-SI natural fibres
# [1507/3163] OK: Kollamat
# [1508/3163] OK: Komanda
# [1509/3163] OK: Decorated Lava Stone
# [1510/3163] OK: Freehand drawing
# [1511/3163] OK: Silk screen printed lava stone
# [1512/3163] OK: Koraflex
# [1513/3163] OK: Koroseal
# [1514/3163] OK: Koskilaser
# [1515/3163] OK: Koskisound
# [1516/3163] OK: Koukoutsi
# [1517/3163] OK: Kova Textiles
# [1518/3163] OK: Kovalex
# [1519/3163] OK: Koyo Ibushi Arare
# [1520/3163] OK: Koyo Ibushi Tiles
# [1521/3163] OK: Koziol
# [1522/3163] OK: Kraftplex relief
# [1523/3163] OK: Kraftplex
# [1524/3163] OK: Aluminium chain links
# [1525/3163] OK: KristalPrint
# [1526/3163] OK: Kromatafor
# [1527/3163] OK: Krystal Weave
# [1528/3163] OK: Kugelgarn
# [1529/3163] OK: Kuii
# [1530/3163] OK: KuiperFoam
# [1531/3163] OK: Kuipertec
# [1532/3163] OK: Kumiko
# [1533/3163] OK: KUMPU
# [1534/3163] OK: Kunrader® stone
# [1535/3163] OK: Kuori
# [1536/3163] OK: Kurz Foils
# [1537/3163] OK: Kynol Fibres and Textiles
# [1538/3163] OK: L-SIM
# [1539/3163] OK: Lace 3D print on tulle
# ...
# [2667/3163] OK: Steel floor tiles
# [2668/3163] OK: Steel tiles
# [2669/3163] OK: Steel
# [2670/3163] OK: SteenFineer (stone veneer)
# [2671/3163] OK: Stegplatten
# [2672/3163] OK: Stellanyl
# [2673/3163] OK: Steni Nature Glass
# [2674/3163] OK: Stimulite Honeycomb
# [2675/3163] OK: Stitch on PVC
# [2676/3163] OK: Stitched Wood
# [2677/3163] OK: Stitched
# [2678/3163] OK: Stitching
# [2679/3163] OK: Sto-Ecoshapes
# [2680/3163] OK: Sto-Glass Mosaic
# [2681/3163] OK: StoBrick
# [2682/3163] OK: StoDeco
# [2683/3163] OK: Stolotusan
# [2684/3163] OK: of-stone
# [2685/3163] OK: Stoneplex Sand
# [2686/3163] OK: Stoneplex Slate
# [2687/3163] OK: StoVentec Glass
# [2688/3163] OK: Strandgut
# [2689/3163] OK: Stratificato Print HPL
# [2690/3163] OK: STRATOS®
# [2691/3163] OK: Straw Board
# [2692/3163] OK: STRAWave
# [2693/3163] OK: Streamribs
# [2694/3163] OK: Febrik Textiles
# [2695/3163] OK: Stretch Chrome Film
# [2696/3163] OK: Stretch Maille
# [2697/3163] OK: MaterialDistrict
# [2698/3163] OK: Stretch textile
# [2699/3163] OK: Striding
# [2700/3163] OK: Stripes Galore Collection
# [2701/3163] OK: Structural Skin
# [2702/3163] OK: Structurally coloured bio material
# [2703/3163] OK: Structuran/Decoran
# [2704/3163] OK: Stylish spaces with metallic surfaces
# [2705/3163] OK: Subcutaneous
# [2706/3163] OK: Subli Tech
# [2707/3163] OK: Sublidot
# [2708/3163] OK: Sucre d’Orge
# [2709/3163] OK: Sugarcane Bagasse Composites
# [2710/3163] OK: Sugarcrete®
# [2711/3163] OK: Sugru
# [2712/3163] OK: Sunbrella Timeless & On the Road
# [2713/3163] OK: Supafil
# [2714/3163] OK: Super soft modal blend
# [2715/3163] OK: Superblack
# [2716/3163] OK: SuperFabric
# [2717/3163] OK: Superform Aluminium
# [2718/3163] OK: SuperNature
# [2719/3163] OK: SuperPan Star
# [2720/3163] OK: SuperPan E-Z
# [2721/3163] OK: SuperTherm
# [2722/3163] OK: Superwool
# [2723/3163] OK: suprlabs ++VE
# [2724/3163] OK: suprlabs +VE
# [2725/3163] OK: Surface iQ PVC-free Wallcovering
# [2726/3163] OK: Surface Synergy textile
# [2727/3163] OK: Surfaces Chip and Stick
# [2728/3163] OK: Surfi-Sculpt®
# [2729/3163] OK: Sustainable Chestnut Wood
# [2730/3163] OK: Sustainable paving tile
# [2731/3163] OK: Sustonable
# [2732/3163] OK: Suwide Capricio
# [2733/3163] OK: Swart Tiles
# [2734/3163] OK: SWEDBOARD® Fibre
# [2735/3163] OK: Swirl & Wave Fabric
# [2736/3163] OK: SymbioMat™
# [2737/3163] OK: SymbioMatter FOAM
# [2738/3163] OK: Syndecrete
# [2739/3163] OK: Synlam
# [2740/3163] OK: Synthetic Turf
# [2741/3163] OK: T-paint Loam textured paint
# [2742/3163] OK: Tabu Veneer
# [2743/3163] OK: Tactile textiles
# [2744/3163] OK: Tactility Factory
# [2745/3163] OK: Stone Tadelakt lime plaster
# [2746/3163] OK: Takeo Paper
# [2747/3163] OK: Tandem Acoustics
# [2748/3163] OK: Tao
# [2749/3163] OK: TaOk 3D tiles
# [2750/3163] OK: Taralay
# [2751/3163] OK: Tarnished sequin
# [2752/3163] OK: Tau Carbono
# [2753/3163] OK: Tea Clay
# [2754/3163] OK: Teak Edge Grain
# [2755/3163] OK: Teak End Grain
# [2756/3163] OK: Teakwood Embossing Stainless Steel
# [2757/3163] OK: Teatris
# [2758/3163] OK: Tec Line
# [2759/3163] OK: TECELL
# [2760/3163] OK: Technical Matt
# [2761/3163] OK: Techniclic cladding system
# [2762/3163] OK: Technogel
# [2763/3163] OK: Technology Line
# [2764/3163] OK: Technowood
# [2765/3163] OK: Tecnoglas
# [2766/3163] OK: Tecnoglas Mirror
# [2767/3163] OK: Tectan board
# [2768/3163] OK: tectonitX™
# [2769/3163] OK: TECU Bond
# [2770/3163] OK: TECU Copper and Copper Alloys
# [2771/3163] OK: Tefor
# [2772/3163] OK: Tegris
# [2773/3163] OK: Temal
# [2774/3163] OK: Tempur foam
# [2775/3163] OK: Tencel Lyocell
# [2776/3163] OK: Tendermark Concrete Veneer
# [2777/3163] OK: Tenite Pebbles
# [2778/3163] OK: Tennage special
# [2779/3163] OK: Tennâge Wood Veneer
# [2780/3163] OK: Tensioned Ceiling System
# [2781/3163] OK: Tensotherm Nanogel
# [2782/3163] OK: Terra alchemy
# [2783/3163] OK: Terra collection by Feina
# [2784/3163] OK: Terrart Baguette
# [2785/3163] OK: Terrart
# [2786/3163] OK: Terravetro
# [2787/3163] OK: Terrazhel
# [2788/3163] OK: Terrazzo Lumina
# [2789/3163] OK: Terrazzo Lumineo
# [2790/3163] OK: Terres émaillées
# [2791/3163] OK: Tessuto
# [2792/3163] OK: Tex-tiles
# [2793/3163] OK: Texaa Vibrasto
# [2794/3163] OK: Texaa
# [2795/3163] OK: Texacoustic
# [2796/3163] OK: Texglass
# [2797/3163] OK: Texilar
# [2798/3163] OK: Texlon Foil Systems
# [2799/3163] OK: Texlon
# [2800/3163] OK: Texluce
# [2801/3163] OK: Textile Constructions
# [2802/3163] OK: Textile glass
# [2803/3163] OK: Textile Sensor
# [2804/3163] OK: TEXTILE SOFTWALL + SOFTBLOCK
# [2805/3163] OK: TEXTILE WALLCOVERING
# [2806/3163] OK: Textile/resin composite
# [2807/3163] OK: Textiles by Mae Engelgeer
# [2808/3163] OK: Textiles by Samira Boon
# [2809/3163] OK: Textiles ‘INSECTED’
# [2810/3163] OK: Textreme, Texero
# [2811/3163] OK: Texture bank
# [2812/3163] OK: Texture surfaces
# [2813/3163] OK: Textured Glass
# [2814/3163] OK: Textured synthetic materials
# [2815/3163] OK: Texwood
# [2816/3163] OK: TFL Cool System
# [2817/3163] OK: That’s Caffeine tiles
# [2818/3163] OK: The Better Wae flooring collection
# [2819/3163] OK: The bloq
# [2820/3163] OK: The Breath
# [2821/3163] OK: The Loomia Gentoo Heated Fabric
# [2822/3163] OK: The Mercury Effect
# [2823/3163] OK: The Olive Wood Collection
# [2824/3163] OK: The Original Nettle 3D
# [2825/3163] OK: The production of fatigue
# [2826/3163] OK: The Subtle Power Of Lines
# [2827/3163] OK: The SuprAnodic Collection
# [2828/3163] OK: The Teak Collection
# [2829/3163] OK: The Wall Project
# [2830/3163] OK: The Yarn
# [2831/3163] OK: Theatre
# [2832/3163] OK: Thermafiber
# [2833/3163] OK: Thermafleece
# [2834/3163] OK: Thermagreen
# [2835/3163] OK: Thermaltech Fabric
# [2836/3163] OK: ThermHex PP Honeycomb
# [2837/3163] OK: Thermo Plastic Elastomer
# [2838/3163] OK: Thermobatch
# [2839/3163] OK: Thermochromic Colorcomp
# [2840/3163] OK: Thermochromic glass TPG
# [2841/3163] OK: Thermochromic Ink
# [2842/3163] OK: Thermoclear
# [2843/3163] OK: Thermacool
# [2844/3163] OK: Thermoformed foam
# [2845/3163] OK: Thermoplastic Elastomers
# [2846/3163] OK: Thermoplastic Film
# [2847/3163] OK: Thermoplastic Film
# [2848/3163] OK: Powder coatings Abcite® & Plascoat®
# [2849/3163] OK: Thermowood
# [2850/3163] OK: Thistle
# [2851/3163] OK: Tibetan Cactus Fibres Carpet
# [2852/3163] OK: Tibgrid
# [2853/3163] OK: TiColor
# [2854/3163] OK: Tiger Oak
# [2855/3163] OK: TIMax Decor decorative inlay
# [2856/3163] OK: TIMax GL Glass fibre insulation
# [2857/3163] OK: Timber-Sil
# [2858/3163] OK: Timber terrazzo
# [2859/3163] OK: Timbercrete
# [2860/3163] OK: Time Included Cloth
# [2861/3163] OK: Tinted carbon
# [2862/3163] OK: Tire Veneer
# [2863/3163] OK: Tissavel cleaning materials
# [2864/3163] OK: Tissu Tricote
# [2865/3163] OK: Tissue paper & clay ceramics
# [2866/3163] OK: TitanSilver
# [2867/3163] OK: Titanwood
# [2868/3163] OK: TMF Valencia recycled glass
# [2869/3163] OK: Tomato Fibre Paper
# [2870/3163] OK: Tongkonan Coco Evo Bliss
# [2871/3163] OK: Topakustik
# [2872/3163] OK: TOPIA TEGEL
# [2873/3163] OK: Toplin Top Coat Gloss
# [2874/3163] OK: Topperfo
# [2875/3163] OK: TORCETEX
# [2876/3163] OK: Torzo Orient
# [2877/3163] OK: Totomoxtle
# [2878/3163] OK: Touch of Nature
# [2879/3163] OK: Touch of Nature, walking on Coffee
# [2880/3163] OK: Tactile textiles in faced panels
# [2881/3163] OK: TPE elastics, tube and cord
# [2882/3163] OK: TRADITION Cork floor tiles
# [2883/3163] OK: Traditional Indian natural dyes
# [2884/3163] OK: Train
# [2885/3163] OK: Transparent Solar Cells
# [2886/3163] OK: Transparenz
# [2887/3163] OK: Transpor Dry Layer
# [2888/3163] OK: TRAshell
# [2889/3163] OK: Tree Free Paper
# [2890/3163] OK: Tree of Culture
# [2891/3163] OK: Treekind®
# [2892/3163] OK: Treeplast
# [2893/3163] OK: Trend Glamour
# [2894/3163] OK: Trespa® Meteon® Lumen Diffuse L9000
# [2895/3163] OK: Trespex B.W. Colored
# [2896/3163] OK: tretford’s special feature
# [2897/3163] OK: TRI – the material that touches you
# [2898/3163] OK: Triaxial Woven Fabric
# [2899/3163] OK: Tribar facade solutions
# [2900/3163] OK: Tribar floor solutions
# [2901/3163] OK: Tricoya
# [2902/3163] OK: Trifilon Revo®
# [2903/3163] OK: Trifilon Switch®
# [2904/3163] OK: TriFold
# [2905/3163] OK: Tritan copolyester
# [2906/3163] OK: Tropical Splash
# [2907/3163] OK: Trosifol
# [2908/3163] OK: Formica® Patterns & Truescale Laminates
# [2909/3163] OK: TT Sheet
# [2910/3163] OK: TTURA
# [2911/3163] OK: Tundra – Techno
# [2912/3163] OK: TUOHI
# [2913/3163] OK: Turmeric as ‘mood booster’
# [2914/3163] OK: Twentinox Fabrics
# [2915/3163] OK: Twincolour
# [2916/3163] OK: Twinson
# [2917/3163] OK: TX Active
# [2918/3163] OK: Typha insulation
# [2919/3163] OK: Tyvek UV Façade & Tyvek Roofliner
# [2920/3163] OK: U-Turn
# [2921/3163] OK: UHPC Facade Panels
# [2922/3163] OK: Ultra Lightweight Concrete
# [2923/3163] OK: Ultra thin stone veneer
# [2924/3163] OK: Ultra thin tulle
# [2925/3163] OK: UltraGlass
# [2926/3163] OK: Ultrasonic quilting
# [2927/3163] OK: Uncomfortable
# [2928/3163] OK: Underlite Flooring
# [2929/3163] OK: Underneath a Surface
# [2930/3163] OK: Unfinished Freshwater Mother of Pearl Tiles
# [2931/3163] OK: Unico
# [2932/3163] OK: Unismooth
# [2933/3163] OK: Unravel
# [2934/3163] OK: Untreated Cast Iron panels
# [2935/3163] OK: Unwasted
# [2936/3163] OK: (Un)woven
# [2937/3163] OK: Uonuon
# [2938/3163] OK: Upcycled Carbon Black
# [2939/3163] OK: UPM Formi
# [2940/3163] OK: UPM Grada
# [2941/3163] OK: UPM ProFi composite
# [2942/3163] OK: Urban paper collection
# [2943/3163] OK: Urban Reef
# [2944/3163] OK: Urban Velvet LU
# [2945/3163] OK: Urban Velvet
# [2946/3163] OK: Urine-Glaze
# [2947/3163] OK: UVMax
# [2948/3163] OK: Vacupor
# [2949/3163] OK: Vacuum-moulding
# [2950/3163] OK: Valchromat coloured MDF
# [2951/3163] OK: Valchromat
# [2952/3163] OK: Vanceva
# [2953/3163] OK: VanHier: Biocircular table lamps
# [2954/3163] OK: Vapourguard
# [2955/3163] OK: Varaform
# [2956/3163] OK: Varioline
# [2957/3163] OK: Varioplan Plus
# [2958/3163] OK: VarioTrans
# [2959/3163] OK: VD-works surface design
# [2960/3163] OK: Vectogramm
# [2961/3163] OK: Vector glass
# [2962/3163] OK: Vectran
# [2963/3163] OK: Vegetable tanned salmon leather
# [2964/3163] OK: Vegetables 2D
# [2965/3163] OK: Vegetables 3D
# [2966/3163] OK: Veilish
# [2967/3163] OK: Velero Textile
# [2968/3163] OK: Velvet Indigo
# [2969/3163] OK: Veneer in Veneer
# [2970/3163] OK: Veneer, moulded / rotary cut
# [2971/3163] OK: Ventri cow stomach leather
# [2972/3163] OK: Veriflex
# [2973/3163] OK: Veritas resinart
# [2974/3163] OK: VeroMetal and shop interiors
# [2975/3163] OK: VeroMetal® Antimicrobial
# [2976/3163] OK: VeroMetal Applications
# [2977/3163] OK: VeroMetal AquaFill® metal stucco
# [2978/3163] OK: VeroMetal
# [2979/3163] OK: Versato Crystal
# [2980/3163] OK: Versato Myst
# [2981/3163] OK: Versato Translucent Stone
# [2982/3163] OK: Versato
# [2983/3163] OK: Versawall & Versapanel
# [2984/3163] OK: Vertigo – concrete
# [2985/3163] OK: VeSta & KuQua tiles
# [2986/3163] OK: VestaEco LDF
# [2987/3163] OK: Vetro vivo
# [2988/3163] OK: Vetroseta
# [2989/3163] OK: Vibers
# [2990/3163] OK: VIBRATO
# [2991/3163] OK: Vicrtex
# [2992/3163] OK: Vidom Glasstiles
# [2993/3163] OK: Vielshield
# [2994/3163] OK: Vifour
# [2995/3163] OK: VILLIglas Tiles
# [2996/3163] OK: Vingui Noir
# [2997/3163] OK: Vintage Leather Belt
# [2998/3163] OK: Vinterio
# [2999/3163] OK: vinyl aqua tiles
# [3000/3163] OK: Vinyl in welded Designs
# [3001/3163] OK: VINYL WALLCOVERING
# [3002/3163] OK: VIP (Vacuum Insulated Panel)
# [3003/3163] OK: Viro™
# [3004/3163] OK: Viroc Unsanded
# [3005/3163] OK: Viroc
# [3006/3163] OK: Virtuell Vertrieb
# [3007/3163] OK: Visu Glass Blocks
# [3008/3163] OK: Vita Talalay latex
# [3009/3163] OK: Vitrics Screen
# [3010/3163] OK: Vitrics
# [3011/3163] OK: Vitrulan »Magnet»
# [3012/3163] OK: Vitrum
# [3013/3163] OK: Vivo
# [3014/3163] OK: Volimea
# [3015/3163] OK: voorBIJ© roadside grass paper
# [3016/3163] OK: Vorwerk Scale
# [3017/3163] OK: Vubonite
# [3018/3163] OK: Vuré Noir
# [3019/3163] OK: Waffle fabric
# [3020/3163] OK: WALA-Eco-Clip
# [3021/3163] OK: Wall panel 067
# [3022/3163] OK: Wall panel
# [3023/3163] OK: Wall+ wall panels
# [3024/3163] OK: Walled-Paper
# [3025/3163] OK: Wallpaper tile
# [3026/3163] OK: Paper Tiles
# [3027/3163] OK: Wallstix
# [3028/3163] OK: Walton Uni & Walton Cirrus
# [3029/3163] OK: Warmbeton
# [3030/3163] OK: Warp-knitted fabrics with Naia™
# [3031/3163] OK: Washi Artisan Parchment
# [3032/3163] OK: Washi HPL
# [3033/3163] OK: Wastea
# [3034/3163] OK: WasteBasedBrick
# [3035/3163] OK: WasteBasedGlaze
# [3036/3163] OK: Water resistant paper
# [3037/3163] OK: Water Tiles
# [3038/3163] OK: Waterstruck bricks multi sintered
# [3039/3163] OK: WavCor
# [3040/3163] OK: WAVETHRU
# [3041/3163] OK: WaxedWood (Color)
# [3042/3163] OK: WDS Ultra
# [3043/3163] OK: WEAVE concrete tiles
# [3044/3163] OK: Weavewood
# [3045/3163] OK: Web Art Pebble Beach
# [3046/3163] OK: Wedi Panel
# [3047/3163] OK: Welded Vinyl
# [3048/3163] OK: Wellboard
# [3049/3163] OK: WellTEC – Big Wave
# [3050/3163] OK: WellTec & PlanTec
# [3051/3163] OK: wet-green
# [3052/3163] OK: Whisky Barrel Flooring
# [3053/3163] OK: Wild silk
# [3054/3163] OK: Willow paper
# [3055/3163] OK: WINCOS Vision Control Film
# [3056/3163] OK: Window Protect Trevira
# [3057/3163] OK: Wintan recycled leather
# [3058/3163] OK: Wire cloth
# [3059/3163] OK: Wire Mesh
# [3060/3163] OK: Wire netting
# [3061/3163] OK: Wireglass
# [3062/3163] OK: WISA Plywood
# [3063/3163] OK: Woelbstruktur
# [3064/3163] OK: Wolffish Leather
# [3065/3163] OK: Wolwaeren Collection
# [3066/3163] OK: Wonder Peach
# [3067/3163] OK: Wonderland
# [3068/3163] OK: Wood, cork & Perspex
# [3069/3163] OK: Wood Fibre Textiles
# [3070/3163] OK: Wood look
# [3071/3163] OK: Wood mosaic
# [3072/3163] OK: Wood paper
# [3073/3163] OK: Wood Plastic Composite
# [3074/3163] OK: Wood Reinvented
# [3075/3163] OK: Wood-skin
# [3076/3163] OK: Wood textile
# [3077/3163] OK: Wood veneer – Roble Collection
# [3078/3163] OK: Wood Wool Design tiles
# [3079/3163] OK: Wood wool panels
# [3080/3163] OK: Woodcarved Panels
# [3081/3163] OK: Wooden colour
# [3082/3163] OK: Wooden Textile
# [3083/3163] OK: Wooden Textiles
# [3084/3163] OK: Wooden wall panels
# [3085/3163] OK: Pavatex woodfibre insulation boards
# [3086/3163] OK: Woodflow-skin
# [3087/3163] OK: WoodFrame Slim Oak PreConsumer
# [3088/3163] OK: WoodFrame Slim Reclaimed Meranti PostConsumer
# [3089/3163] OK: Woodio®
# [3090/3163] OK: WoodLeather
# [3091/3163] OK: Woodloop
# [3092/3163] OK: Woodnotes Paper Yarn
# [3093/3163] OK: Formica® Woods Laminates
# [3094/3163] OK: Woodstone
# [3095/3163] OK: Woodsure
# [3096/3163] OK: Woodwool carpet
# [3097/3163] OK: Wool-Aluminium
# [3098/3163] OK: Wool & biobased plastic Carpet
# [3099/3163] OK: Wool Felt
# [3100/3163] OK: Wool Felt: i-did x Hollands Wol Collectief
# [3101/3163] OK: Wool Fugenband
# [3102/3163] OK: Wool laminated
# [3103/3163] OK: Wool wall
# [3104/3163] OK: Wool with Cashmere
# [3105/3163] OK: Wool XL Pied de Poule
# [3106/3163] OK: Wootex
# [3107/3163] OK: WooWood
# [3108/3163] OK: Workwear Cordura Dobby
# [3109/3163] OK: Workwear Cordura stretch
# [3110/3163] OK: Workwear nylon PVC dot
# [3111/3163] OK: Woven Animation
# [3112/3163] OK: Woven Goat
# [3113/3163] OK: Woven Grass Paper
# [3114/3163] OK: Woven light textiles
# [3115/3163] OK: Woven Panels
# [3116/3163] OK: Woven recycled LLDPE
# [3117/3163] OK: Woven recycled material
# [3118/3163] OK: Woven wood
# [3119/3163] OK: Woven Wool
# [3120/3163] OK: Wovenint
# [3121/3163] OK: Wovin wall
# [3122/3163] OK: Wrapping & Specialty tapes
# [3123/3163] OK: X-KIN®
# [3124/3163] OK: X-LAM
# [3125/3163] OK: X-LED
# [3126/3163] OK: X-tend
# [3127/3163] OK: Xanita
# [3128/3163] OK: xceldesign
# [3129/3163] OK: XILO
# [3130/3163] OK: Xiriton with Olivine
# [3131/3163] OK: Xiriton
# [3132/3163] OK: XL EXTRALIGHT
# [3133/3163] OK: Xorel
# [3134/3163] OK: Xotic Bamboo felt
# [3135/3163] OK: Xtegra
# [3136/3163] OK: Xtreme Leather
# [3137/3163] OK: Xyhlo
# [3138/3163] OK: Xylogramm
# [3139/3163] OK: XYMARA Effect Pigments
# [3140/3163] OK: Y Shield
# [3141/3163] OK: YD-Woods
# [3142/3163] OK: YiBrick Breeze Blocks
# [3143/3163] OK: YiBrick – Handmade & Permeable Brick
# [3144/3163] OK: YiTile
# [3145/3163] OK: Yoroi
# [3146/3163] OK: Yosima
# [3147/3163] OK: Younique®
# [3148/3163] OK: YST Noodles
# [3149/3163] OK: YST White Clinic
# [3150/3163] OK: YST (You See Through)
# [3151/3163] OK: Yulex neoprene
# [3152/3163] OK: Zanders paper Collection
# [3153/3163] OK: Zapp Precision Strip
# [3154/3163] OK: Zazza
# [3155/3163] OK: ZEBRA
# [3156/3163] OK: Zelfo
# [3157/3163] OK: Zephyr Mesh
# [3158/3163] OK: Zero.4
# [3159/3163] OK: Zero furniture panel
# [3160/3163] OK: Zero
# [3161/3163] OK: Zinc Foam
# [3162/3163] OK: Zintek – Titanium zinc
# [3163/3163] OK: Zwartz Non-woven

# %% [markdown]
# ## 14. Normalize into DataFrame

# %%
def flatten_record(d):
    flat = {
        "url": d["url"],
        "material_name": d.get("material_name"),
        "Category": d.get("Category"),
        "Code": d.get("Code"),
        "Country": d.get("Country"),
        "Brand": d.get("Brand"),
        "post_text": d.get("post_text"),
        "tags": ", ".join(d.get("tags", [])),
    }
    # Flatten properties
    for group, props in d.get("material_properties", {}).items():
        for k, v in props.items():
            flat[f"{group}_{k}"] = v
    return flat

flat_results = [flatten_record(r) for r in results]
df = pd.DataFrame(flat_results)

# %% [markdown]
# ## 15. Save to CSV

# %%
df.to_csv("materials_data.csv", index=False)
print("Saved materials_data.csv with", len(df), "rows and", len(df.columns), "columns.")
# Out:
# Saved materials_data.csv with 3163 rows and 23 columns.
